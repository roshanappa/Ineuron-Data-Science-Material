# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# - Inside the hypothesis we have do the statstical analysis and finally we will come up with some conclusions.
# - If we have population and if we want make some assumption on top that for that we can not do immedietly because the population's data is in bulcky.
# - In order to get the some assumption of top population we have take random sample and make analysis on top that by using the statstical techniques like Chi2_test,Annove test and T_test and make then come up with some colculsion at the  end.

# %% [markdown]
# ### There are two types of hypothesis testing.

# %% [markdown]
# The person is criminal or not.

# %% [markdown]
# In the case we have taken the significant value that is `P_value = 0.05`.

# %% [markdown]
# - `1.Null Hypothesis(Ho):-` Person is innocent.
# - `2.Alternate Hypothesis(H1):-`Person is criminal
# - `Experiments :-` Find the evidances like fingureprint,wapean,DNA sample and do statstical anlysis by using some techniques.
# -  `Conclusions :-`After doing all statstical operation we will conclude the result P_value,
# - If the `resultant P_value<=0.05` then our null hypothesis will get rejetced and our alternate hypothesis will get accepted.

# %% [markdown]
# ## About `P_value`

# %% [markdown]
# - If you can see that we have space bar in ur computer and each we mostly press it at the middle of it and due to this reason we have got the normal distribution.
# - We have to consider all the area under the curve is equal to 1.
# - Where we have found p_value like we have `p_value =0.01 and p_value =0.8` at different location of curve.

# %% [markdown]
# - Let's assume that we do have symmetric gaussian distributed curve and we `confident interval = Ci = 95 = 0.95`
# - We have an `P_value = 0.05`
# - `Ci = 1-0.05 = 0.95`
# - If we have symmetrical data or gaussian distributed data in that case our P_value will get splitted equally in 0.025 at the both ends of the curve.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The **`P_value`** will decide with the help of the domain expert.

# %% [markdown]
# For an example
#
# - If we have critical **`p_value`** which is decided by the domain expert that is about **`0.05`** and
# - If we do some statstical analysis we have found the our **`experimented P_value`** is equal to the **`0.07`**.That means it will lays inside the **`95% confidence interval`** and accept the **`null_hypothsis`** and Reject the **`Alternate_Hypothesis.`**
# - For some reason if we will get the **`experimented P_value`**  equal to the **`0.001`**.That will be laying down in critical zone that means our **`null hypothesis`** will get rejected and our **`Alternate hypothesis`** will get selected.

# %% [markdown]
# #### Link :-  `https://www.geo.fu-berlin.de/en/v/soga/Basics-of-statistics/Hypothesis-Tests/Introduction-to-Hypothesis-Testing/Critical-Value-and-the-p-Value-Approach/index.html`

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### About the `Confidence Interval( CI )`

# %% [markdown]
# It is but how much % of spreadness do we required from mean of data itself.

# %% [markdown]
# - A confidence interval (CI) is a type of estimate computed from the statistics of the observed data. This gives a range of values for an unknown parameter (for example, a population mean).
# - The interval has an associated confidence level that gives the probability with which an estimated interval will contain the true value of the parameter.
# - The confidence level is chosen by the investigator. For a given estimation in a given sample, using a higher confidence level generates a wider (i.e., less precise) confidence interval.
# - In general terms, a confidence interval for an unknown parameter is based on sampling the distribution of a corresponding estimator.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ways Of getting an understanding of the Null Hypothesis and Alternate Hypothesis.

# %% [markdown]
# - P_value :- It is can be obtained with the help of some stastical techniques.
# - Table  :- By using the **`Z-Table,T-Table and F-Table`** we will calculate the Upper Bound and Lower Bound and estimate wheather we are getting in 95% confidence interval range in order to accept the null hypothesis or not.

# %% [markdown]
# - **`P_value`** Can able to get with the help of **`Coding.`**
# - **`Region value`** Can able to get with the help of **`Table or Theorotical way.`**

# %% [markdown]
# #### How to calculate the Confidence Interval ?

# %% [markdown]
# Before going ahead to know about how to calculate the Confidence Interval we really need to know about the **`Point Estimate.`**

# %% [markdown]
# #### Point Estimate :- The value of any stastic that estimate the value of a parameter is called as a point estimate.

# %% [markdown]
# Example :-Point estimate is nothing but we are going to estimate the mean of population with the help of mean of sample.

# %% [markdown]
# Here mue is going to estimate the population mean.

# %% [markdown]
# #### **`Point_Estimate`** is going to be calculate we have population standard deviation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Alpha is nothing but the critical values and Z is the z_score,small n is sample population.

# %% [markdown]
# #### What is the  **`Margine Of Error`** ?

# %% [markdown]
# The left and right hand side portion from the mean of sample data called as positive and negetive margine respectively.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Problem 1:-  if Population standard deviation is given

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Standard Deviation is about the population.

# %% [markdown]
# Here in above question we have
#
# - Std_of_Population = `sigma` = 100
# - n = 25
# - sample_mean = 520
# - ci = 45%

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If we want to calculate the **`Z_score`** that time we have to use the **`Z_table`** lets see

# %% [markdown]
# ### Link :- https://www.math.arizona.edu/~rsims/ma464/standardnormaltable.pdf

# %% [markdown]
# - If we see we want to get first upon the left hand side area of the normally ditributed curve for that we have done calculation.
#
# - **`1-0.025=0.975`**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now see the **`Z_table`** and finding the position with value **`0.975`**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Then we will two values over there
#
# - **`1.Z Value`**
# - **`2.Area to the left the z_score.`**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We will get the final values **`Z_Score`** that is **`1.9+0.06 = 1.96`**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Both side we will `Z_Score` `+1.96 and -1.96`

# %% [markdown]
# This is about plus margine error value

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is about minus margine error value

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If the value of sample mean will be lay in range of **`559.2`** and **`480.8`**  with **`95% Cofidence Interval`** then our null hypothesis will be accept otherwise will be reject.

# %% [markdown]
# In that we have found the upper bound and lower bound by using the stastical techniques.

# %% [markdown]
# By observing the question our null hypothesis is become our mean which is already given inside question.

# %% [markdown]
# - Null Hypothesis is getting accept because the value of sample's mean is laying inside the upper and lower bound.
# - Alternate Hypothesis is will rejected.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Problem 2:-  if Population standard deviation is not given

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Calculate the margine of error

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# In this problem statement we do not have population standard deviation so in this problem statement we have the value of degree of freedom.

# %% [markdown]
# Drgree of Freedom:- Degrees of Freedom refers to the maximum number of logically independent values, which are values that have the freedom to vary, in the data sample.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In this we have to find the **`T-Table`**

# %% [markdown]
# ### Link :- https://www.sjsu.edu/faculty/gerstman/StatPrimer/t-table.pdf

# %% [markdown]
# Inside the T-table we have an x and y axis
#
# - In the X axis we have the t values like 0.05 critical p_value
# - In the y axis we have the degree of freedom

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Finally,we have got an result for `critical value 0.05 is 2.064` and this is for two-tailed.

# %% [markdown]
# By using the that T_test value we are getting an our upper and lower Bound

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If you see our mean of the sample it is about the 520 and it laying inbetweem the upper and lower Bound so from that we can our Null hypothsis will get accepted and our alternate hypothesis will rejected.

# %% [markdown]
# When the population standard deviation will not given then we have to dependent on the degree of freedom.

# %% [markdown]
# The T test is called as F1 error.

# %% [markdown]
# **`Whenever we use the Z_test,our sample size should be greater than equal to 30.`**

# %% [markdown]
# **`Degree of Freedom means how many number of chances we have like that.`**

# %% [markdown]
# ## Statstical Tests

# %% [markdown]
# There are two test are avalible that are :-
#
# - **`1.Z-Test (Comparision of the mean)`** :- Here we do have population standard deviation.
# - **`2.T-Test (Comparison of the mean)`**  :- Here we do not have population standard deviation.
# - **`3.F-Test  (Comparision of Variance)`**
# - **`4.Annova-Test (Analysis of Variance)`**
# - **`5.Chi2_Test (Comparision between two categorical Variables)`**

# %% [markdown]
# ## 1.One-Sample Z_Test

# %% [markdown]
# For the one sample Z_test we should know two things
#
# - Population standard Deviation
# - Sample size should be greater than and equal to 30.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In the above example we have an average pupulation of IQ is equal to 100 and we are checking with new medication test IQ value will decrease or increase.
#
# For that we really want to understand the curve.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We have **`significant value=Alpha = 0.05`** and and we want to whether it is going to increase or decrease so in order to analysis we will use **`two tail test`** because it is increases in one side and decreases at begining side of the normally distributed curve.

# %% [markdown]
# Here we have calculate the z_score like we have did by using z table,In that table we have to calculate two tailed value and Z and add together.

# %% [markdown]
# #### Things we can get from problem statement.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If we calcualte the **`Z_test`** stastics score it will be like below way.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And our Z_test score will be ranging inbetween the **`-1.96 to 1.96`**.

# %% [markdown]
# If you calculate the **`Z_Score`** by using the **`Z_test`** and the we have got the value which is nothing but the **`14.60`** and this is not avaliable in the range that is avaliable **`-1.96 and 1.96`**.

# %% [markdown]
# **`Thus we are rejecting the null hypothesis and aceepting alternate hypothesis.`**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - If suppose we want to make the analysis by the **`one tail test`** then we have to consider the problem statement as did the medication either increase or decrease intellegence.

# %% [markdown]
# My Alternate Hypothesis will become :- Mean will be greater than 100.

# %% [markdown]
# - If suppose we want to make the analysis by the **`one tail test`** then we have to consider the problem statement as did the medication is decrease intellegence.

# %% [markdown]
# My Alternate Hypothesis will become :- Mean will be lesser than 100.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Task 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - population_mean = 110
# - std = 15
# - two tailed test
# - sample_size >= 30 means it is good for z_test
# - sample_size = 35
# - Sample_mean = 120
# - significant_value = 0.05

# %% [markdown]
# - null_hypothesis = mean is equal to 110
# - alternate_hypothesis = mean is not equal to 110

# %% [markdown]
# If we want to calculate the **`Z_Score`**,in that case we can do it with the help of Z_table,for that we need to do some operation.
#
# - left_hand_area = 1-0.025 = 0.975
# - Then afterword if we can calculated the Z_score based on our data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Calculating the Z_Score by using Z_table areal Stastics.

# %% [markdown]
# **`left_hand_area = 1-alpha/2 = 1-0.05/2 = 1-0.025 = 0.975`**
# - Try to find this value inside the Z_table and on the basis of that we will calculate the Critical Z value.
# - **`Z_score = 1.9+0.06 = 1.96`**

# %% [markdown]
# That will be like below way.
#
# - **Z_Score :-`1.9+0.06=1.96`**

# %% [markdown]
# #### Calculating the Z_Score by using Z_test Stastics.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Z_score of the Z_test = -3.944 = -3.944

# %% [markdown]
# **`Z_score`** from area based approaches is lower than the **`Z_score`** which we had calculated by using simple **`Z_score Test`** from that we can say our null hypothesis is getting rejected and our alternate hypothesis is getting accepted.

# %% [markdown]
# Whichever the Z_score comming from critical alpha value or significat value should be greater than the Z_Score which will be comming from the Z_test in order to accept the Null Hypothesis.

# %% [markdown]
# From the above statement  we can conclude that it will increase the intellgence.

# %% [markdown]
# https://www.youtube.com/watch?v=zJ8e_wAWUzE

# %% [markdown]
# #### Difference inbetween the Z_Score and Z_Test.

# %% [markdown]
# - Z_Score :- It require the population data like mean and Standard Deviation.
#
# - Z_Test :- It required the sample parameter like size,standard Deviation and Sample Standard Error.

# %% [markdown]
# ## 2.One-Sample T_Test

# %% [markdown]
# - It used whenever we do have population Standard Deviation.
# - Number of sample should not be greater than equal to 30.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here the Significant value is equal To :- **`alpha = 0.05`**

# %% [markdown]
# - Null_Hypothesis = 100
# - Alternative_Hypothesis = Not equal To 100
# - Degree of freedom = **`25-1 = 24`**
# - It is two tailed Test
# - Aplha value will be = **`alpha/2 = 0.05/2 = 0.025 for each tail normal graph.`**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After calculating Z_Score that is nothing but
#
# - **2.064**
#
# We can showcase like below way

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If you can see that t-test value is getting 10 which is bigger than the 2.064 that means we are rejecting the null hypothesis and accepting the alternate hypothesis.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Conclusion :- Medication has increase the intellegence.

# %% [markdown]
# ## 3.One-Sample Z_Test Proportion

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We have proportion so for that we have different formuale in order to calculate the Z_Score.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Here, **`-2.667 < -0.843274`**.

# %% [markdown]
# It means that our claim which was given about the null hypothsis about proportion was not correct from that we can say that
# our null hypothesis is rejected and our alternative hypothesis is getting accepted.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
