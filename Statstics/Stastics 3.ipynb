# %% [markdown]
# - 1.Five number theory
# - 2.Correlation,Covariance
# - 3.Hypothesis Testing
# - 5.Outliers

# %% [markdown]
# ## Five Number Theory

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here,75% and 25% are the percentile not percentage.

# %% [markdown]
# Suppose

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If we got the 45 percentile of the 7 number that basically indicating that it is 45% of the overall distribution belonging to only for data which is less than 7.

# %% [markdown]
# Example :- Here the number of values blow X means ..a number of data which is avalible below 7 number inside the avalible data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If we want to calculate the value below which we will get the 25% then
#
# Here n = 14 means number of data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 25% of data distribution  getting below 3.75 that inbetween 3 and 4.

# %% [markdown]
# ### Outliers Removing technique.

# %% [markdown]
# In order to remove the outliers we have make the lower fence and upper fence for the data.Whicher the comes outside the lower and uppper bound or fence are called as outliers and we have to reomve that outliers.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### How to remove an outlier ?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Step 1:- First it will sort the data.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Step2 :- Find the index position of the values where the 25 percentile and 75 percentile will exist.If we can see at the 4.25 position we have rounded that rank position 4 and then fnd data on that position.like 7 and 105.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Step 3:- Find the lower and upper fence or bound.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After removing an outliers then only we have calculate the median.

# %% [markdown]
# In this case we have got the 5 summary of the data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Box plot.
#
# - Inside the box plot we should have the 5 points that are `min,25% percentile,medium,75% percentile and maximun`.
# - we have calculate the median on top the data which is not considering outliers data.
# -  If we can see after the 1000 at the 15 location of sorted data point we are considering them as an outliers.
# - medium value value is not at middle of box that is why we can say that it following gaussian distribution.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Task 1

# %%
data = {5,6,7,2,15,35,88,77,65,52,42,15,105,208,199,1000}

# %% [markdown]
# - Min = 2
# - Max = 1000

# %% [markdown]
# - Medium

# %%
data_sort = {2,5,6,7,15,15,35,42,52,65,77,88,105,199,208,10000}

# %% [markdown]
# - Medium needs to be calcuate after removing the outliers.

# %% [markdown]
# `n` is nothing number of data point inside the data.

# %% [markdown]
# - 25_percntile_index = 25/100*(n+1)
# - 25_percentile_index = 4.25 = 4
#
#
# - 75_percntile_index = 75/100*(n+1)
# - 75_percentile_index = 12

# %% [markdown]
# After getting an index position of sorted data point inside data.We can get thier exact values and by using that values we can calculate the `IQR`.The index postion has to be round off.

# %% [markdown]
# - `IQR = Q3-Q1 = 88-7 = 81`

# %% [markdown]
# - Lower_fence = `Q1 - 1.5(IQR)`  = 7 - 1.5(81) = -114.5
# - Upper_fence = `Q3  + 1.5(IQR)` = 88   + 1.5(81) =  209.5

# %% [markdown]
# #### Box plot.
#
# - Inside the box plot we should have the 5 points that are `min,25% percentile,medium,75% percentile and maximun`.
# - we have calculate the median on top the data which is not considering outliers data.
# -  If we can see after the 15 point data we are considering them as an outliers.
# - medium value value is not at middle of box that is why we can say that it following gaussian distribution.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# https://www.mathsisfun.com/data/percentiles.html

# %% [markdown]
# ### Covariance

# %% [markdown]
# - Covariance is a statistical tool that is used to determine the relationship between the movement of two variables.
# - When we have two variables tend to move together, they are seen as having a positive covariance and; when they move inversely, the covariance is negative.
# - It means that if X is moving y.If X is decreaase then Y is getting decrease that is called as positive Covaraince.
# - When the X is getting decrease whereas the Y will get increase,it means that there is negetive Covariance.
# - Covariance is a significant tool in modern portfolio theory used to ascertain what securities to put in a portfolio.
# - Risk and volatility can be reduced in a portfolio by pairing assets that have a negative covariance.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Positive and Negetive Correlation :-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Stastical Graph for Positive,Negetive and No Correlation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Inside the covariance,we do not have the any exact range to identify the how much is getting correlated with another variable.
#
# It does quantify the relationship and in the return it will provide us the value which shows us the wheather it is positive correlated or negetive correlated but how much correlated is not getting disclosed.

# %% [markdown]
# In order to do so we have an option that is nothing but **`Correlation`**.

# %% [markdown]
# ## Pearson Correlation Coeficient.

# %% [markdown]
# - In the pearson correlation coeficient we are restrict the range inbetween `-1 to 1`.
# - In Covariance if data will be avaliable in high magnitude then it will return covariance in  higher magnitude but will not show us that how much correlated two variable to each other.
# - For that purpose we are going to use the Pearson Correlation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Possitive and Negetive Correlation :-

# %% [markdown]
# - X1,X2 and X3 are independ feature and Y is the dependent feature.
# - Here we we can first X1 and X2 are highly correlated or (+ve) with Y variable.
# - X3 is highly negetive correlated with Y variable.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Feature Engineering Technique.

# %% [markdown]
# If suppose we have two independent variable and two are highly correlated with dependent feature that time we have to drop one of them the independent feature.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here,we can say that X1 and X2 are independent feature and they are highly correlated with

# %% [markdown]
# The correlation by default will applicable for the numerical data only.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Spearman's Rank Correlation Coeficient.

# %% [markdown]
# - In order to capture more non-linear relation properties we use the Spearman Rank Correlation Coeficient.
# - If we can see the below image the as X is increase the Y is also getting increase but in such situation pearson correlation is getting the 0.88 whereas the Spearman Correlation is getting 1 because it takes consideration of non-liear properties of data.

# %% [markdown]
# - In pearson correlation we should have straight line to get the proper result.
# - In Spearman Rank Coefiencient we can handel the non linear property of data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If we can see the formula for the Spearman Rank Coefiencient.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - First we have calculate the X and Y rank on basis of their magnitude.
# - Use the formuale on top of that
# - Covariance of rank
# - Divide By
# - Standard Deviation of both Ranks.

# %% [markdown]
# #### Application :-

# %% [markdown]
# How the Correlation works for the data ?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# By default,It uses the pearson correlation and sometimes we have to provide the method in order to calculate the correlation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Central Limit Theorem

# %% [markdown]
# - If we have random variable X and which may or may not be follow the Gaussian distribution with some mean value and standard Deviation.
# - If I will take sample is n>=30 from the random variable every time in each sample.In that may value of sample may get repeat.
# - In similarly,we have m number sample
# - If we calculate the mean of each sample
# - Plot a distribution plot
# - It will gives use Normaly distributed Graph
# - That will be have mean approx to the population mean and standard deviation below way

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Explaination :-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hypothesis Testing.

# %% [markdown]
# When we have population and then we have to take random sample from that population in order make assumptions.

# %% [markdown]
# Because we can not take the whole pupulation to get the pure assumption but instead of that we will take sample data and use statstical technique to get conclusion from the data.

# %% [markdown]
# Example:- If we have data of 1000 customer and you have 100th year of celebration in that you want to give each customer a T-shirt but you dont know which size of T-shirt they will prefer mostly.In this we will take sample data from population make some assumption of top of that by using statstical techniques.like chi2_test,annova,t_test etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Steps for Hypothesis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example :-

# %% [markdown]
# - If the person has done crime then is he innicent or not lets solve issue with hypothesis testing.
# - Inside the hypothesis our null hypothesis is person is not guilty until its proven
# - Alternate hypothesis shows that person is criminal.
# - We collect evidances,DNA,fingureprint and then do experient on top of that and
# - Make some colclusion of data we have data
# - Decide that person is guilty or not.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Thank You  !!
