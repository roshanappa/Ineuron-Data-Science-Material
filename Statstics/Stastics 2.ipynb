# %% [markdown]
# ## Measure Of Dispersion

# %% [markdown]
# For any kind data we have distribution but as we go ahea we should know know how our is spreaded in order to calculate that we have some measures.

# %% [markdown]
# ### Variance

# %% [markdown]
# It is nothing but the measure of spread.

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
# It is actually help us to find the how the element is away from the mean.

# %% [markdown]
# For mean of sample we have (n) and for mean of population we usually prefer to use thee (N).

# %% [markdown]
# Spred,variance,std Deviation,Gaussion Dstribution,Types of distribution and its properties.

# %% [markdown]
# Gaussian Distributon :- x axis will contain std and y axis PDF.Stardard Normal Distribution has property that mean =0 and std=1

# %% [markdown]
# Histogram :- It is basically for quantitative variable.X axis is for bins and y axis is for frequency.Bins are nothing but the bucket or division of all the data in range of bucket.Like if we have 0-100 age data and for making the histogram we will consider the one bin is lies 0-10 range.

# %% [markdown]
# Z_Score :- If we have data and I want to know about where the data point willl lying inside gaussian distribution.For that we will use the Z-Score.

# %% [markdown]
# Application of Z Score :-
#
# - Standardization

# %% [markdown]
# #### Example :-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In which year team performed well.If we compare with z_score of 2020 and 2021.From there I can say team peroformed well in the 2021 than 2020.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# By using Z_score we can compare of the different distribution.

# %% [markdown]
# Probablity :-

# %% [markdown]
# Probability is the branch of mathematics concerning numerical descriptions of how likely an event is to occur, or how likely it is that a proposition is true. The probability of an event is a number between 0 and 1, where, roughly speaking, 0 indicates impossibility of the event and 1 indicates certainty.

# %% [markdown]
# - Mutual Exclusive event :- Event which will be not possible to occure at time.
# - Non-Mutual Exclusive event :- Event which can be possible to occure at time.

# %% [markdown]
# Additive rule or Additive probablity :-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Multiplicative Probablity :-

# %% [markdown]
# Independent and dependent event

# %% [markdown]
# 1.Independent Event

# %% [markdown]
# Inside the rolling dice the each ouput probablity is independent and no affecting to each other,so they called as independent event.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1.Dependent Event

# %% [markdown]
# If we can see that we have 5 balls and each have different colour.
# If first took out the white ball and then that time probablity is 1/5 and if again try to fetch the red ball then we have an probablity 1/4.From here we can say the our lasted red ball probablity is depends upon the while ball probablity.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Example 1. About the Independent event.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Example 2. About the Dependent event.

# %% [markdown]
# The latest event probablity is depends upon the last even probablity is called as dependent event.In this case the white ball has fetched from bag and then again we fetch the red ball from the same bag.In that case we have to first calculate the red ball probablity and then calculate the red ball probablity given white ball probality.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is called as conditional probablity.

# %% [markdown]
# #### Application Of Probablity

# %% [markdown]
# Naive Bayes Algorithm,Classification algorithm.

# %% [markdown]
# Permutation and Combination :-

# %% [markdown]
# #### Permutation

# %% [markdown]
# How many possible comes the data called as permutation.

# %% [markdown]
# - If you go the zoo and there you will get the task that which animan you have seen first and u have write on the 3 given papers.
# - You can see the you can see six of out of six and then you see five and then u can see 4.
# - All possible combination with all element is 120.
# - Orderwise it will become 120.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It gives us all possible outcomes from the zoo.

# %% [markdown]
# #### Combination :-

# %% [markdown]
# Inside the combination the repeated terms counted as 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.tutorialspoint.com/statistics/combination.htm

# %% [markdown]
# #### Outliers:-
