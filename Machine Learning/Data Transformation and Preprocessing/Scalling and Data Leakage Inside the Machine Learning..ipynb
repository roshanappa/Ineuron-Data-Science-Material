# %% [markdown]
# ## Scalling In Machine Learning.

# %% [markdown]
# - In the machine learning we have lot of feature in the different ranges and magnitude.
# - While training the model we required the feature in the numerical format.
# - Each column having their own behaviour that is why they have diffrent magnitude.
# - In the machine learning we required distance measurement from base line espcially whenver we do have parametrc approach in the particular algorithm like KNN,Linear Regression,Logistic Regression etc.
# - This meansurement should be so far for regression because model will get overfitted because of high variance in other word data points will be avaliable far away from its mean and alorithm takes lot of training time because it usually takes time to cover each point in order get train.

# %% [markdown]
# Meanwhile some algorithm gives higher importance to higher magnitude even it is not important as far as our business decision concern like some 1000 gram is equal 1 kg.
# In this case algorithm gives high important to 1000 gram not to the 1 Kg.
# In order to avoid this kind of problem we really required scalling.

# %% [markdown]
# ## Standardization and Normalization.

# %% [markdown]
# It is nothing but the transforming the data in certain range or in common scale.

# %% [markdown]
# ## Diffrence Between .fit(),transform() and fit.transform()

# %% [markdown]
# - Difference between fit(), transform() & fit_transform() ❗❗
#
#  - Scikit-Learn has objects called Transformer. The use of a transformer is that it will be performing data preprocessing & feature transformation. For example StandardScaler, Imputer, MinMaxScaler etc.
#
#  - Suppose we take f1, f2, f3 & f4 feature where f1,f2,f3 are independent and f4 is dependent feature and we apply a standardization process in which it takes a feature F and converts into F' by applying a formula of standardization. If you notice at this stage we take one input Feature F and convert it into other input feature F' itself. So in this condition we do 3 different operation:
#
# - ⏩fit(), transform() & fit_transform()⏮
#
# - 👉fit(): Suppose we initialize the StandardScaler object O and we do .fit() then, it takes the feature F and it will just  compute the mean (μ) and standard deviation (σ) of feature F.
#
# - 👉transform(): For changing the data we probably do transform, where we apply the calculations that we have calculated in fit() to every data point in feature F. We have to use .transform() in front of a fit object because we transform the fit calculations.
#
# - 👉fit_transform(): This fit_transform() method is basically the combination of fit method and transform method.

# %% [markdown]
# ## Data Leakage.

# %% [markdown]
# - As soon as we build the model with good accuracy and deploy that model over the cloud.
# - Whenever it gets the unseen the data the prediction is getting bad.
# - Return the bad accuaracy.

# %% [markdown]
# - The below way of Train and test data is getting devided and making prediction according to the flow.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Due to practices the some of data inside the train data is getting shared with test data vice versa.
# - This is how the model will give us good accuarcy at the end.
# - Most of times it happen during data processing steps and feature engineering steps.
# - Sometimes the missing value we put before splitting the datasets into train and test and that is bad practices.
# - Sometime we do data transformation by using the standarscaler and before spliting data into the train and test split that also bad practice and leads to overfit the model.
