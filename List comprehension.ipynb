# %% [markdown]
# ## List Comprehension.

# %% [markdown]
# - One main benefit of using a list comprehension in Python is that it’s a single tool that you can use in many different situations. In addition to standard list creation, list comprehensions can also be used for mapping and filtering. You don’t have to use a different approach for each scenario.
#
# - This is the main reason why list comprehensions are considered Pythonic, as Python embraces simple, powerful tools that you can use in a wide variety of situations. As an added side benefit, whenever you use a list comprehension in Python, you won’t need to remember the proper order of arguments like you would when you call map().
#
# - List comprehensions are also more declarative than loops, which means they’re easier to read and understand. Loops require you to focus on how the list is created. You have to manually create an empty list, loop over the elements, and add each of them to the end of the list. With a list comprehension in Python, you can instead focus on what you want to go in the list and trust that Python will take care of how the list construction takes place.

# %% [markdown]
# #### Link :- `https://realpython.com/list-comprehension-python/#:~:text=Remove%20ads-,Benefits%20of%20Using%20List%20Comprehensions,than%20loops%20or%20map()%20.&text=List%20comprehensions%20are%20also%20more,how%20the%20list%20is%20created.`

# %% [markdown]
# ### Normal Example.

# %%
lst =[22,55,66,778,89]

# %%
for i in lst: 
    print(i)
# Out:
# 22
# 55
# 66
# 778
# 89

# %% [markdown]
# In the above example,we have created the list and iterate with the help of for loop but it is taking the two lines of code.

# %% [markdown]
# ### List Comprehension Approch

# %% [markdown]
# It is jsut way throgh which can also do it the same thing but in different way.

# %%
[i for i in lst]
# Out:
# [22, 55, 66, 778, 89]

# %%
[[i for i in lst]]
# Out:
# [[22, 55, 66, 778, 89]]

# %% [markdown]
# ### List Comprehension Approach with conditions.

# %% [markdown]
# #### Syntax :-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Normal Example

# %%
for i in range(10):
    if i%2==0:
        print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# ### List Comprehension Example.

# %%
[i for i in range(10) if i%2==0]
# Out:
# [0, 2, 4, 6, 8]

# %%
sentence = 'the rocket came back from mars'
vowels = [i for i in sentence if i in 'aeiou']
vowels
# Out:
# ['e', 'o', 'e', 'a', 'e', 'a', 'o', 'a']

# %% [markdown]
# ### Normal Example.

# %%
lst =[]

for i in range(10):
    if i%2==0:
        lst.append('Even')
    else:
        lst.append('Odd')

# %%
lst
# Out:
# ['Even', 'Odd', 'Even', 'Odd', 'Even', 'Odd', 'Even', 'Odd', 'Even', 'Odd']

# %% [markdown]
# ### List Comprehension way

# %%
['Even' if i%2 ==0  else 'Odd' for i in range(10)]
# Out:
# ['Even', 'Odd', 'Even', 'Odd', 'Even', 'Odd', 'Even', 'Odd', 'Even', 'Odd']

# %% [markdown]
# **For getting any kind of output we have write the condition of `if ` before the `for loop` and for the sake of `filter` we have to write the if condition  after the `for loop`**

# %% [markdown]
# ### Normal Example.

# %%
mat =[]

for i in range(3):
    mat.append([])
    for j in range(3):
        mat[i].append(j)
        
mat
# Out:
# [[0, 1, 2], [0, 1, 2], [0, 1, 2]]

# %% [markdown]
# ### List Comprehension way

# %%
[[j for j in range(3)] for i in range(3)]
# Out:
# [[0, 1, 2], [0, 1, 2], [0, 1, 2]]

# %% [markdown]
# ### List Comprehension with multiple conditions

# %%
[i for i in range(10) if i%2==0 if i%3==0] #it is nothing but the multiple condition with the help of if statement.
# Out:
# [0, 6]

# %% [markdown]
# ### List Comprehension with multiple conditions

# %%
['yes' if i==1 else 'No' for i in range(10)]
# Out:
# ['No', 'yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No']

# %%
['yes' if i==1 else 'No' if i==2 else 'Not' for i in range(10)]
# Out:
# ['Not', 'yes', 'No', 'Not', 'Not', 'Not', 'Not', 'Not', 'Not', 'Not']

# %% [markdown]
# https://www.programiz.com/python-programming/list-comprehension

# %% [markdown]
# ## Thanks !!
