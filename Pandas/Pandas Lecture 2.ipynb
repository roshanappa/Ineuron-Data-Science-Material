# %% [markdown]
# ## Pandas 2

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool')

# %%
data = data[3]

# %%
pickle_file = data.to_pickle('Pickel_file')

# %%
data.to_csv('html_data.csv')

# %%
from_file = pd.read_csv('html_data.csv')

# %% [markdown]
# ### h5 file Storing data.

# %%
h5_data = pd.HDFStore("test.h5") #binary storage of data.

# %%
h5_data['Obj1'] = from_file

# %%
h5_data['Obj1']
# Out:
#     Unnamed: 0     Season   Age   Tm   Lg  Pos      G     GS      MP     FG  \
# 0            0    2009-10  20.0  OKC  NBA   PF    6.0    0.0   153.0   20.0
# 1            1    2010-11  21.0  OKC  NBA   PF   17.0   17.0   490.0   67.0
# 2            2    2011-12  22.0  OKC  NBA   PF   20.0   20.0   569.0   84.0
# 3            3    2012-13  23.0  OKC  NBA   PF   11.0   11.0   366.0   59.0
# 4            4    2013-14  24.0  OKC  NBA   PF   17.0   17.0   581.0   87.0
# 5            5    2015-16  26.0  OKC  NBA   PF   18.0   18.0   602.0   85.0
# 6            6    2016-17  27.0  TOR  NBA   PF   10.0   10.0   307.0   60.0
# 7            7    2017-18  28.0  TOR  NBA   PF   10.0    9.0   260.0   30.0
# 8            8    2018-19  29.0  TOR  NBA    C   24.0    0.0   500.0   92.0
# 9            9    2019-20  30.0  TOR  NBA    C   11.0    0.0   251.0   63.0
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0
# ...

# %%
h5_data.put('obj1',from_file,format='table')

# %%
h5_data.select('obj1',where=['index >= 10 and index<=15'])
# Out:
#     Unnamed: 0     Season   Age   Tm   Lg  Pos      G     GS      MP     FG  \
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0
# 11          11     Career   NaN  NaN  NBA  NaN  146.0  102.0  4097.0  650.0
# 12          12        NaN   NaN  NaN  NaN  NaN    NaN    NaN     NaN    NaN
# 13          13  6 seasons   NaN  OKC  NBA  NaN   89.0   83.0  2761.0  402.0
# 14          14  4 seasons   NaN  TOR  NBA  NaN   55.0   19.0  1318.0  245.0
# 15          15   1 season   NaN  LAC  NBA  NaN    2.0    0.0    18.0    3.0
#
#     ...    FT%    ORB    DRB    TRB    AST   STL    BLK    TOV     PF     PTS
# 10  ...  1.000    1.0    3.0    4.0    2.0   1.0    3.0    1.0    1.0    10.0
# 11  ...  0.792  275.0  680.0  955.0  109.0  61.0  292.0  139.0  448.0  1599.0
# 12  ...    NaN    NaN    NaN    NaN    NaN   NaN    NaN    NaN    NaN     NaN
# 13  ...  0.768  200.0  399.0  599.0   47.0  42.0  222.0   74.0  283.0   971.0
# ...

# %% [markdown]
# - This operation called as SERDE or Serialization operation,it help us to convert the object to byte code.
# - The operation called as Deserialization operation,it help us to convert byte code to the object.

# %% [markdown]
# ### Read_csv

# %%
data = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
round(data.describe(),1)
# Out:
#        PassengerId  Survived  Pclass    Age  SibSp  Parch   Fare
# count        891.0     891.0   891.0  714.0  891.0  891.0  891.0
# mean         446.0       0.4     2.3   29.7    0.5    0.4   32.2
# std          257.4       0.5     0.8   14.5    1.1    0.8   49.7
# min            1.0       0.0     1.0    0.4    0.0    0.0    0.0
# 25%          223.5       0.0     2.0   20.1    0.0    0.0    7.9
# 50%          446.0       0.0     3.0   28.0    0.0    0.0   14.5
# 75%          668.5       1.0     3.0   38.0    1.0    0.0   31.0
# max          891.0       1.0     3.0   80.0    8.0    6.0  512.3

# %%
data.dtypes[data.dtypes=="object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
data.dtypes[data.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
type(data.dtypes)
# Out:
# pandas.core.series.Series

# %%
df1=data[data.dtypes[data.dtypes=="object"].index]

# %%
df1.describe()
# Out:
#                             Name   Sex  Ticket    Cabin Embarked
# count                        891   891     891      204      889
# unique                       891     2     681      147        3
# top     Daly, Mr. Eugene Patrick  male  347082  B96 B98        S
# freq                           1   577       7        4      644

# %%
data.dtypes == "float64"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
data.dtypes[data.dtypes == "float64"]
# Out:
# Age     float64
# Fare    float64
# dtype: object

# %%
data.dtypes[data.dtypes == "float64"].index
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
data['Name'][0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
data['Name'][0:10]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
sorted(data['Ticket'])
# Out:
# ['110152',
#  '110152',
#  '110152',
#  '110413',
#  '110413',
#  '110413',
#  '110465',
#  '110465',
#  '110564',
#  '110813',
#  '111240',
#  '111320',
#  '111361',
#  '111361',
#  '111369',
#  '111426',
#  '111427',
#  '111428',
#  '112050',
#  '112052',
#  '112053',
#  '112058',
#  '112059',
#  '112277',
#  '112379',
#  '113028',
#  '113043',
#  '113050',
#  '113051',
#  '113055',
#  '113056',
#  '113059',
#  '113501',
#  '113503',
#  '113505',
#  '113505',
#  '113509',
#  '113510',
#  '113514',
#  '113572',
#  '113572',
#  '113760',
#  '113760',
#  '113760',
#  '113760',
#  '113767',
#  '113773',
#  '113776',
#  '113776',
#  '113781',
#  '113781',
#  '113781',
#  '113781',
#  '113783',
#  '113784',
#  '113786',
#  '113787',
#  '113788',
#  '113789',
#  '113789',
#  '113792',
#  '113794',
#  '113796',
#  '113798',
#  '113798',
#  '113800',
#  '113803',
#  '113803',
#  '113804',
#  '113806',
#  '113806',
#  '113807',
#  '11668',
#  '11668',
#  '11751',
#  '11751',
#  '11752',
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
for i in data.columns:
    print(data[i])
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# ...

# %% [markdown]
# ### Insert the new Column.

# %%
data['Roshan'] = 'Roshan'

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Roshan
# 0      0         A/5 21171   7.2500   NaN        S  Roshan
# 1      0          PC 17599  71.2833   C85        C  Roshan
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Roshan
# 3      0            113803  53.1000  C123        S  Roshan
# ...

# %%
data['Passenger1'] = data['PassengerId']

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Roshan  Passenger1
# 0      0         A/5 21171   7.2500   NaN        S  Roshan           1
# 1      0          PC 17599  71.2833   C85        C  Roshan           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Roshan           3
# ...

# %%
pd.Categorical(data['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
pd.Categorical(data['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(data['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data['Sex'].nunique()
# Out:
# 2

# %%
data['Pclass'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
data[data['Pclass'].isnull()==False].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Roshan  Passenger1
# 0      0         A/5 21171   7.2500   NaN        S  Roshan           1
# 1      0          PC 17599  71.2833   C85        C  Roshan           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Roshan           3
# ...

# %%
ser= data['Pclass'][data['Pclass'].isnull()==False].head()

# %%
ser
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: Pclass, dtype: int64

# %%
ser.index
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
data.iloc[ser.index]#rowwise extraction of data
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Roshan  Passenger1
# 0      0         A/5 21171   7.2500   NaN        S  Roshan           1
# 1      0          PC 17599  71.2833   C85        C  Roshan           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Roshan           3
# ...

# %%
data.iloc[[1,6,5,4,7]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 6            7         0       1
# 5            6         0       3
# 4            5         0       3
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 4                           Allen, Mr. William Henry    male  35.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
#
#    Parch    Ticket     Fare Cabin Embarked  Roshan  Passenger1
# 1      0  PC 17599  71.2833   C85        C  Roshan           2
# 6      0     17463  51.8625   E46        S  Roshan           7
# 5      0    330877   8.4583   NaN        Q  Roshan           6
# ...

# %%
ser1= data['Age'][data['Age'].isnull()==True]

# %%
len(ser1)
# Out:
# 177

# %%
data['Fare']==max(data['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
data[data['Fare']==max(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      Roshan  Passenger1
# 258  Roshan         259
# 679  Roshan         680
# 737  Roshan         738

# %%
data[data['Fare']==max(data['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
data['New_Col'] = data['PassengerId']+data['Age']

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Roshan  Passenger1  \
# 0      0         A/5 21171   7.2500   NaN        S  Roshan           1
# 1      0          PC 17599  71.2833   C85        C  Roshan           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Roshan           3
# ...

# %%
pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep="\t")
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ## Data Sources

# %% [markdown]
# - https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt
# - https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv
# - https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv
# - https://drive.google.com/file/d/1etGP85wJWsgqbsh3gX5oxc8dPKLMA1eT/view

# %% [markdown]
# ### Thanks !
