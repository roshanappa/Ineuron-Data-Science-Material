# %% [markdown]
# ## Data Manupulation.

# %%
import pandas as pd
titanic_train = pd.read_csv('titanic.csv')
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(titanic_train)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(titanic_train.dtypes)
# Out:
# pandas.core.series.Series

# %%
dy = titanic_train.dtypes

# %%
dy['Cabin']
# Out:
# dtype('O')

# %%
dy
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dy[:4]
# Out:
# PassengerId     int64
# Survived        int64
# Pclass          int64
# Name           object
# dtype: object

# %%
type(titanic_train['Age'])
# Out:
# pandas.core.series.Series

# %%
list(titanic_train['Age'])[::2]
# Out:
# [22.0,
#  26.0,
#  35.0,
#  54.0,
#  27.0,
#  4.0,
#  20.0,
#  14.0,
#  2.0,
#  31.0,
#  35.0,
#  15.0,
#  8.0,
#  nan,
#  nan,
#  40.0,
#  nan,
#  28.0,
#  nan,
#  18.0,
#  40.0,
#  nan,
#  19.0,
#  nan,
#  nan,
#  7.0,
#  49.0,
#  65.0,
#  21.0,
#  5.0,
#  22.0,
#  45.0,
#  nan,
#  29.0,
#  17.0,
#  32.0,
#  21.0,
#  32.0,
#  nan,
#  0.83,
#  22.0,
#  nan,
#  17.0,
#  16.0,
#  23.0,
#  29.0,
#  46.0,
#  59.0,
#  71.0,
#  34.0,
#  28.0,
#  21.0,
#  37.0,
#  21.0,
#  38.0,
#  47.0,
#  22.0,
#  17.0,
#  70.5,
#  24.0,
#  21.0,
#  32.5,
#  54.0,
#  nan,
#  nan,
#  33.0,
#  47.0,
#  25.0,
#  19.0,
#  16.0,
#  nan,
#  24.0,
#  18.0,
#  27.0,
#  36.5,
#  51.0,
#  55.5,
#  nan,
#  16.0,
#  nan,
#  44.0,
#  26.0,
#  1.0,
#  nan,
#  nan,
#  61.0,
#  1.0,
#  56.0,
#  nan,
#  30.0,
#  nan,
#  9.0,
#  4.0,
#  nan,
#  40.0,
#  32.0,
#  19.0,
#  44.0,
#  nan,
#  nan,
#  28.0,
#  34.0,
#  18.0,
#  32.0,
#  16.0,
#  24.0,
#  22.0,
#  nan,
#  27.0,
#  32.0,
#  16.0,
#  51.0,
#  38.0,
#  19.0,
#  18.0,
#  35.0,
#  59.0,
#  24.0,
#  44.0,
#  19.0,
#  nan,
#  29.0,
#  30.0,
#  25.0,
#  37.0,
#  nan,
#  62.0,
#  41.0,
#  nan,
#  35.0,
#  nan,
#  52.0,
#  nan,
#  16.0,
#  58.0,
#  nan,
#  41.0,
#  nan,
#  45.0,
#  7.0,
#  65.0,
#  16.0,
#  nan,
#  30.0,
#  42.0,
#  26.0,
#  36.0,
#  24.0,
#  23.5,
#  nan,
#  nan,
#  19.0,
#  nan,
#  nan,
#  30.0,
#  24.0,
#  26.0,
#  43.0,
#  24.0,
#  31.0,
#  22.0,
#  30.0,
#  nan,
#  61.0,
#  31.0,
#  nan,
#  38.0,
#  nan,
#  29.0,
#  45.0,
#  2.0,
#  28.0,
#  36.0,
#  40.0,
#  3.0,
#  23.0,
#  15.0,
#  nan,
#  22.0,
#  nan,
#  40.0,
#  45.0,
#  nan,
#  60.0,
#  nan,
#  25.0,
#  19.0,
#  3.0,
#  22.0,
#  20.0,
#  42.0,
#  32.0,
#  nan,
#  1.0,
#  nan,
#  36.0,
#  28.0,
#  24.0,
#  31.0,
#  23.0,
#  39.0,
#  21.0,
#  20.0,
#  51.0,
#  21.0,
#  nan,
#  33.0,
#  44.0,
#  34.0,
#  30.0,
#  nan,
#  29.0,
#  18.0,
#  28.0,
#  nan,
#  28.0,
#  42.0,
#  50.0,
#  21.0,
#  64.0,
#  45.0,
#  25.0,
#  nan,
#  13.0,
#  5.0,
#  36.0,
#  30.0,
#  nan,
#  65.0,
#  50.0,
#  48.0,
#  47.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  33.0,
#  22.0,
#  34.0,
#  22.0,
#  9.0,
#  50.0,
#  25.0,
#  35.0,
#  30.0,
#  nan,
#  55.0,
#  21.0,
#  54.0,
#  25.0,
#  17.0,
#  nan,
#  16.0,
#  33.0,
#  28.0,
#  29.0,
#  36.0,
#  24.0,
#  34.0,
#  36.0,
#  30.0,
#  nan,
#  nan,
#  50.0,
#  39.0,
#  2.0,
#  17.0,
#  30.0,
#  45.0,
#  nan,
#  36.0,
#  11.0,
#  50.0,
#  19.0,
#  33.0,
#  17.0,
#  nan,
#  22.0,
#  48.0,
#  39.0,
#  nan,
#  28.0,
#  nan,
#  19.0,
#  nan,
#  62.0,
#  36.0,
#  16.0,
#  34.0,
#  nan,
#  25.0,
#  54.0,
#  nan,
#  47.0,
#  22.0,
#  35.0,
#  47.0,
#  37.0,
#  nan,
#  nan,
#  24.0,
#  nan,
#  35.0,
#  30.0,
#  22.0,
#  39.0,
#  nan,
#  35.0,
#  34.0,
#  4.0,
#  27.0,
#  20.0,
#  21.0,
#  57.0,
#  26.0,
#  80.0,
#  32.0,
#  9.0,
#  32.0,
#  41.0,
#  20.0,
#  2.0,
#  0.75,
#  19.0,
#  nan,
#  nan,
#  21.0,
#  18.0,
#  nan,
#  23.0,
#  50.0,
#  47.0,
#  20.0,
#  25.0,
#  43.0,
#  40.0,
#  70.0,
#  nan,
#  24.5,
#  43.0,
#  nan,
#  20.0,
#  60.0,
#  14.0,
#  18.0,
#  31.0,
#  nan,
#  60.0,
#  44.0,
#  49.0,
#  18.0,
#  18.0,
#  26.0,
#  45.0,
#  22.0,
#  24.0,
#  48.0,
#  52.0,
#  38.0,
#  nan,
#  6.0,
#  34.0,
#  27.0,
#  30.0,
#  25.0,
#  29.0,
#  nan,
#  23.0,
#  48.0,
#  nan,
#  nan,
#  21.0,
#  31.0,
#  16.0,
#  19.0,
#  4.0,
#  33.0,
#  48.0,
#  28.0,
#  34.0,
#  nan,
#  20.0,
#  16.0,
#  nan,
#  nan,
#  24.0,
#  57.0,
#  54.0,
#  nan,
#  nan,
#  13.0,
#  29.0,
#  25.0,
#  18.0,
#  1.0,
#  nan,
#  nan,
#  25.0,
#  49.0,
#  30.0,
#  34.0,
#  11.0,
#  27.0,
#  39.0,
#  39.0,
#  26.0,
#  35.0,
#  30.5,
#  23.0,
#  43.0,
#  52.0,
#  38.0,
#  2.0,
#  nan,
#  nan,
#  15.0,
#  nan,
#  18.0,
#  21.0,
#  32.0,
#  20.0,
#  30.0,
#  17.0,
#  nan,
#  28.0,
#  4.0,
#  9.0,
#  44.0,
#  45.0,
#  24.0,
#  41.0,
#  48.0,
#  24.0,
#  27.0,
#  nan,
#  26.0,
#  33.0,
#  28.0,
#  20.0,
#  nan,
#  25.0,
#  22.0,
#  25.0,
#  27.0,
#  nan,
#  32.0]

# %%
titanic_train['Age'][-1] #it is not helping to get the Age in -1 indexing.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# F:\anaconda\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-8ae94be568fd> in <module>
# ----> 1 titanic_train['Age'][-1] #it is not helping to get the Age in -1 indexing.
#
# F:\anaconda\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# F:\anaconda\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# F:\anaconda\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     355                     return self._range.index(new_key)
#     356                 except ValueError as err:
# --> 357                     raise KeyError(key) from err
#     358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: -1

# %%
round(titanic_train.describe(),2)
# Out:
#        PassengerId  Survived  Pclass     Age   SibSp   Parch    Fare
# count       891.00    891.00  891.00  714.00  891.00  891.00  891.00
# mean        446.00      0.38    2.31   29.70    0.52    0.38   32.20
# std         257.35      0.49    0.84   14.53    1.10    0.81   49.69
# min           1.00      0.00    1.00    0.42    0.00    0.00    0.00
# 25%         223.50      0.00    2.00   20.12    0.00    0.00    7.91
# 50%         446.00      0.00    3.00   28.00    0.00    0.00   14.45
# 75%         668.50      1.00    3.00   38.00    1.00    0.00   31.00
# max         891.00      1.00    3.00   80.00    8.00    6.00  512.33

# %%
titanic_train.dtypes[titanic_train.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic_train.dtypes[titanic_train.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic_train[titanic_train.dtypes[titanic_train.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
titanic_train[titanic_train.dtypes[titanic_train.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
titanic_data_cat = titanic_train[titanic_train.dtypes[titanic_train.dtypes == 'object'].index]

# %%
titanic_data_cat.describe()
# Out:
#                       Name   Sex Ticket        Cabin Embarked
# count                  891   891    891          204      889
# unique                 891     2    681          147        3
# top     Jonkoff, Mr. Lalio  male   1601  C23 C25 C27        S
# freq                     1   577      7            4      644

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(titanic_train[['Name' ,'Fare' ]])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train[['Name']]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
import numpy as np
titanic_train_age_null = np.where(titanic_train['Age'].isnull() == True) #this is the row indexes.

# %%
titanic_train[titanic_train['Age'].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5      male  NaN      0      0      330877   8.4583   NaN        Q
# 17     male  NaN      0      0      244373  13.0000   NaN        S
# 19   female  NaN      0      0        2649   7.2250   NaN        C
# 26     male  NaN      0      0        2631   7.2250   NaN        C
# 28   female  NaN      0      0      330959   7.8792   NaN        Q
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male  NaN      0      0      345777   9.5000   NaN        S
# 878    male  NaN      0      0      349217   7.8958   NaN        S
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [177 rows x 12 columns]

# %%
titanic_train_age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
#         839, 846, 849, 859, 863, 868, 878, 888], dtype=int64),)

# %% [markdown]
# ### Data Filteration.

# %%
titanic_train.iloc[titanic_train_age_null] #age null value filteration according to the row indexes.
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5      male  NaN      0      0      330877   8.4583   NaN        Q
# 17     male  NaN      0      0      244373  13.0000   NaN        S
# 19   female  NaN      0      0        2649   7.2250   NaN        C
# 26     male  NaN      0      0        2631   7.2250   NaN        C
# 28   female  NaN      0      0      330959   7.8792   NaN        Q
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male  NaN      0      0      345777   9.5000   NaN        S
# 878    male  NaN      0      0      349217   7.8958   NaN        S
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [177 rows x 12 columns]

# %%
titanic_train.iloc[5] #this is about the 5th row in dataframe.
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
titanic_train.iloc[[1,4,6,85,55]]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 4             5         0       3
# 6             7         0       1
# 85           86         1       3
# 55           56         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 85  Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female  33.0      3
# 55                                  Woolner, Mr. Hugh    male   NaN      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 4       0    373450   8.0500   NaN        S
# 6       0     17463  51.8625   E46        S
# 85      0   3101278  15.8500   NaN        S
# 55      0     19947  35.5000   C52        S

# %%
titanic_train[titanic_train['Fare']==titanic_train['Fare'].max()]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic_train.iloc[np.where(titanic_train['Fare']==max(titanic_train['Fare']))]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic_train[titanic_train['Age']==24]['Name']
# Out:
# 89                                Celotti, Mr. Francesco
# 118                             Baxter, Mr. Quigg Edmond
# 127                            Madsen, Mr. Fridtjof Arne
# 139                                   Giglio, Mr. Victor
# 142    Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 199               Yrois, Miss. Henriette ("Mrs Harbeck")
# 210                                       Ali, Mr. Ahmed
# 234                    Leyson, Mr. Robert William Norman
# 247                      Hamalainen, Mrs. William (Anna)
# 293                                  Haas, Miss. Aloisia
# 294                                     Mineff, Mr. Ivan
# 310                       Hays, Miss. Margaret Bechstein
# 316                  Kantor, Mrs. Sinai (Miriam Sternin)
# 341                       Fortune, Miss. Alice Elizabeth
# 345                        Brown, Miss. Amelia "Mildred"
# 369                        Aubart, Mme. Leontine Pauline
# 394    Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...
# 437                Richards, Mrs. Sidney (Emily Hocking)
# 499                                   Svensson, Mr. Olof
# 514                                    Coleff, Mr. Satio
# 565                                 Davies, Mr. Alfred J
# 600    Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...
# 615                                  Herman, Miss. Alice
# 641                                 Sagesser, Mlle. Emma
# 655                            Hickman, Mr. Leonard Mark
# 710     Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")
# 743                                    McNamee, Mr. Neal
# 770                               Lievens, Mr. Rene Aime
# 858                Baclini, Mrs. Solomon (Latifa Qurban)
# 864                               Gill, Mr. John William
# Name: Name, dtype: object

# %%
titanic_train.iloc[np.where(titanic_train['Age']==min(titanic_train['Age']))]['Name']
# Out:
# 803    Thomas, Master. Assad Alexander
# Name: Name, dtype: object

# %%
titanic_train[titanic_train['Cabin'].isnull()]['Name']
# Out:
# 0                       Braund, Mr. Owen Harris
# 2                        Heikkinen, Miss. Laina
# 4                      Allen, Mr. William Henry
# 5                              Moran, Mr. James
# 7                Palsson, Master. Gosta Leonard
#                          ...
# 884                      Sutehall, Mr. Henry Jr
# 885        Rice, Mrs. William (Margaret Norton)
# 886                       Montvila, Rev. Juozas
# 888    Johnston, Miss. Catherine Helen "Carrie"
# 890                         Dooley, Mr. Patrick
# Name: Name, Length: 687, dtype: object

# %%
titanic_train[['Name' , 'Pclass']]
# Out:
#                                                   Name  Pclass
# 0                              Braund, Mr. Owen Harris       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                             Allen, Mr. William Henry       3
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas       2
# 887                       Graham, Miss. Margaret Edith       1
# 888           Johnston, Miss. Catherine Helen "Carrie"       3
# 889                              Behr, Mr. Karl Howell       1
# 890                                Dooley, Mr. Patrick       3
#
# [891 rows x 2 columns]

# %%
titanic_train[['Age','Cabin']][titanic_train.Cabin.isnull()==True]
# Out:
#       Age Cabin
# 0    22.0   NaN
# 2    26.0   NaN
# 4    35.0   NaN
# 5     NaN   NaN
# 7     2.0   NaN
# ..    ...   ...
# 884  25.0   NaN
# 885  39.0   NaN
# 886  27.0   NaN
# 888   NaN   NaN
# 890  32.0   NaN
#
# [687 rows x 2 columns]

# %%
titanic_train[titanic_train['Cabin'].isnull()]['Name']
# Out:
# 0                       Braund, Mr. Owen Harris
# 2                        Heikkinen, Miss. Laina
# 4                      Allen, Mr. William Henry
# 5                              Moran, Mr. James
# 7                Palsson, Master. Gosta Leonard
#                          ...
# 884                      Sutehall, Mr. Henry Jr
# 885        Rice, Mrs. William (Margaret Norton)
# 886                       Montvila, Rev. Juozas
# 888    Johnston, Miss. Catherine Helen "Carrie"
# 890                         Dooley, Mr. Patrick
# Name: Name, Length: 687, dtype: object

# %%
titanic_train[((titanic_train['Sex']=='male') & (titanic_train['Survived']==1))]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 17    NaN      0      0  244373  13.0000   NaN        S
# 21   34.0      0      0  248698  13.0000   D56        S
# 23   28.0      0      0  113788  35.5000    A6        S
# 36    NaN      0      0    2677   7.2292   NaN        C
# 55    NaN      0      0   19947  35.5000   C52        S
# ..    ...    ...    ...     ...      ...   ...      ...
# 838  32.0      0      0    1601  56.4958   NaN        S
# 839   NaN      0      0   11774  29.7000   C47        C
# 857  51.0      0      0  113055  26.5500   E17        S
# 869   4.0      1      1  347742  11.1333   NaN        S
# 889  26.0      0      0  111369  30.0000  C148        C
#
# [109 rows x 12 columns]

# %% [markdown]
# ### New_Column Addition.

# %%
titanic_train['New_Col'] = 'Roshan'

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked New_Col
# 0      0         A/5 21171   7.2500   NaN        S  Roshan
# 1      0          PC 17599  71.2833   C85        C  Roshan
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Roshan
# 3      0            113803  53.1000  C123        S  Roshan
# 4      0            373450   8.0500   NaN        S  Roshan

# %% [markdown]
# ### Series

# %%
lst = [12,45,55,66]

# %%
ser=pd.Series(lst)

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser1 = {"One":1,"Two":2,"Three":3,"Four":4}

# %%
pd.Series(ser1)
# Out:
# One      1
# Two      2
# Three    3
# Four     4
# dtype: int64

# %% [markdown]
# ### DataFrame.

# %%
d= {'Number':["One","Two","Three","Four",'Five','Six','Seven','Eight','Nine'],"Integer":list('123456789')}

# %%
dataframe=pd.DataFrame(d,index=list(range(1,10)),columns=['Number','Integer'])
dataframe
# Out:
#   Number Integer
# 1    One       1
# 2    Two       2
# 3  Three       3
# 4   Four       4
# 5   Five       5
# 6    Six       6
# 7  Seven       7
# 8  Eight       8
# 9   Nine       9

# %%
dataframe.dtypes
# Out:
# Number     object
# Integer    object
# dtype: object

# %%
arr = np.random.randn(3,4)

# %%
arr
# Out:
# array([[-0.31598038,  0.69864834, -0.88482544, -0.54325895],
#        [ 0.31803213, -0.92283617,  1.36523286, -0.58603073],
#        [ 0.22758085,  1.12390247, -0.12614124, -0.7385058 ]])

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0 -0.315980  0.698648 -0.884825 -0.543259
# 1  0.318032 -0.922836  1.365233 -0.586031
# 2  0.227581  1.123902 -0.126141 -0.738506

# %%
pd.Series(arr) #series can take only one dimensioanal array.
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-87-409226d0ba63> in <module>
# ----> 1 pd.Series(arr)
#
# F:\anaconda\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     325                     data = data.copy()
#     326             else:
# --> 327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
#     329                 data = SingleBlockManager.from_array(data, index)
#
# F:\anaconda\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     494     elif subarr.ndim > 1:
#     495         if isinstance(data, np.ndarray):
# --> 496             raise Exception("Data must be 1-dimensional")
#     497         else:
#     498             subarr = com.asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %%
ser = pd.Series(np.array([4,5,6,7,8]),index=['a','b','sudh',"kumar",'c'])

# %%
ser
# Out:
# a        4
# b        5
# sudh     6
# kumar    7
# c        8
# dtype: int32

# %%
ser['sudh']
# Out:
# 6

# %%
ser.iloc['sudh']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-dd627bc1611a> in <module>
# ----> 1 ser.iloc['sudh']
#
# F:\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# F:\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1491             key = item_from_zerodim(key)
#    1492             if not is_integer(key):
# -> 1493                 raise TypeError("Cannot index by location index with a non-integer key")
#    1494
#    1495             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
ser.iloc[0]
# Out:
# 4

# %%
ser.loc['sudh']
# Out:
# 6

# %%
ser['sudh']
# Out:
# 6

# %%
ser1 = pd.Series(np.array([4,5,6,7,8]),index=[45,51,62,"sudh",83])

# %%
ser1
# Out:
# 45      4
# 51      5
# 62      6
# sudh    7
# 83      8
# dtype: int32

# %%
ser1.iloc[51]  #This is named indexes but we want the default indexes.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-97-280a5a11aba7> in <module>
# ----> 1 ser1.iloc[51]
#
# F:\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# F:\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1494
#    1495             # validate the location
# -> 1496             self._validate_integer(key, axis)
#    1497
#    1498             return self.obj._ixs(key, axis=axis)
#
# F:\anaconda\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
#    1436         if key >= len_axis or key < -len_axis:
# -> 1437             raise IndexError("single positional indexer is out-of-bounds")
#    1438
#    1439     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
ser1.iloc[:2]
# Out:
# 45    4
# 51    5
# dtype: int32

# %%
ser1.loc[51]
# Out:
# 5

# %%
df = pd.DataFrame(np.random.randint(3,6,(4,5)),index=[1,2,3,4],columns=[1,2,3,4,5])

# %%
df
# Out:
#    1  2  3  4  5
# 1  4  5  4  3  4
# 2  4  3  5  5  4
# 3  4  4  4  5  4
# 4  4  3  3  4  3

# %%
df = pd.DataFrame(np.random.randint(3,6,(4,5)),index=['a','b','c','d'],columns=['x','y','z','u','v'])

# %%
df
# Out:
#    x  y  z  u  v
# a  4  3  4  5  3
# b  5  4  4  5  4
# c  5  4  3  4  4
# d  5  4  3  5  3

# %%
df.iloc[2:,2:4]
# Out:
#    z  u
# c  3  4
# d  3  5

# %%
df.loc[['c','d'],['z','u']]
# Out:
#    z  u
# c  3  4
# d  3  5

# %%
df.iloc[[2,3],[2,3]]
# Out:
#    z  u
# c  3  4
# d  3  5

# %%
df['new']=df['z']+df['z']

# %%
df
# Out:
#    x  y  z  u  v  new
# a  4  3  4  5  3    8
# b  5  4  4  5  4    8
# c  5  4  3  4  4    6
# d  5  4  3  5  3    6

# %%
df.iloc[2:,2:4]
# Out:
#    z  u
# c  3  4
# d  3  5

# %%
df.drop('x',axis=1)
# Out:
#    y  z  u  v  new
# a  3  4  5  3    8
# b  4  4  5  4    8
# c  4  3  4  4    6
# d  4  3  5  3    6

# %%
df
# Out:
#    x  y  z  u  v  new
# a  4  3  4  5  3    8
# b  5  4  4  5  4    8
# c  5  4  3  4  4    6
# d  5  4  3  5  3    6

# %%
df.drop('x',axis=1,inplace=True)

# %%
df
# Out:
#    y  z  u  v  new
# a  3  4  5  3    8
# b  4  4  5  4    8
# c  4  3  4  4    6
# d  4  3  5  3    6

# %%
df = df.drop('a')

# %%
df
# Out:
#    y  z  u  v  new
# b  4  4  5  4    8
# c  4  3  4  4    6
# d  4  3  5  3    6

# %% [markdown]
# ### Negetive values extractions.

# %%
np.random.seed(23)
df = pd.DataFrame(np.random.randn(4,5),index=['a','b','c','d'],columns=['x','y','z','u','v'])

# %%
df
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %%
df[df<0]
# Out:
#           x         y         z         u         v
# a       NaN       NaN -0.777619       NaN       NaN
# b -1.051082 -0.367548 -1.137460 -1.322148       NaN
# c -0.347459       NaN       NaN       NaN -1.043450
# d -1.009942       NaN       NaN -1.838068 -0.938769

# %%
df.values[df.values<0] #convert into the form of array
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
df.values[df.iloc[0:5]<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
df
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %%
for i in df.columns:
    for j in df[i]:
        if j <0:
            print(j)
# Out:
# -1.0510815639071178
# -0.34745899102186334
# -1.0099418765878465
# -0.3675481161171661
# -0.7776194131918178
# -1.1374596907250272
# -1.3221475225908594
# -1.8380677677579502
# -1.0434500017467254
# -0.9387686311201282

# %%
df.values[df.iloc[0:5]<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
df.values[df.values<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
df.values[df.iloc[0:5]<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
for i in df.columns:
    for j in df[i]:
        if j <0:
            print(j,'----',i)
# Out:
# -1.0510815639071178 ---- x
# -0.34745899102186334 ---- x
# -1.0099418765878465 ---- x
# -0.3675481161171661 ---- y
# -0.7776194131918178 ---- z
# -1.1374596907250272 ---- z
# -1.3221475225908594 ---- u
# -1.8380677677579502 ---- u
# -1.0434500017467254 ---- v
# -0.9387686311201282 ---- v

# %%
c = df.values[df.values<0]
for i in df.columns:
    for j in df.index:
        if df.loc[j,i] in c:
            print(i,j)
# Out:
# x b
# x c
# x d
# y b
# z a
# z b
# u b
# u d
# v c
# v d

# %%
l = df.values[df<0]
for c in df.columns:
    for v in df.index:
        if df[c][v] in l:
            print(c,v,df[c][v])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
for i in df.columns:
    for j in df.index:
        if df.loc[j,i]<0:
            print(i,j,df.loc[j,i])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
for i in df.columns:
    for j in df.index:
        for k in df.values[df.values<0]:
            print(k,"----",(i,j))
# Out:
# -0.7776194131918178 ---- ('x', 'a')
# -1.0510815639071178 ---- ('x', 'a')
# -0.3675481161171661 ---- ('x', 'a')
# -1.1374596907250272 ---- ('x', 'a')
# -1.3221475225908594 ---- ('x', 'a')
# -0.34745899102186334 ---- ('x', 'a')
# -1.0434500017467254 ---- ('x', 'a')
# -1.0099418765878465 ---- ('x', 'a')
# -1.8380677677579502 ---- ('x', 'a')
# -0.9387686311201282 ---- ('x', 'a')
# -0.7776194131918178 ---- ('x', 'b')
# -1.0510815639071178 ---- ('x', 'b')
# -0.3675481161171661 ---- ('x', 'b')
# -1.1374596907250272 ---- ('x', 'b')
# -1.3221475225908594 ---- ('x', 'b')
# -0.34745899102186334 ---- ('x', 'b')
# -1.0434500017467254 ---- ('x', 'b')
# -1.0099418765878465 ---- ('x', 'b')
# -1.8380677677579502 ---- ('x', 'b')
# -0.9387686311201282 ---- ('x', 'b')
# -0.7776194131918178 ---- ('x', 'c')
# -1.0510815639071178 ---- ('x', 'c')
# -0.3675481161171661 ---- ('x', 'c')
# -1.1374596907250272 ---- ('x', 'c')
# -1.3221475225908594 ---- ('x', 'c')
# -0.34745899102186334 ---- ('x', 'c')
# -1.0434500017467254 ---- ('x', 'c')
# -1.0099418765878465 ---- ('x', 'c')
# -1.8380677677579502 ---- ('x', 'c')
# -0.9387686311201282 ---- ('x', 'c')
# -0.7776194131918178 ---- ('x', 'd')
# -1.0510815639071178 ---- ('x', 'd')
# -0.3675481161171661 ---- ('x', 'd')
# -1.1374596907250272 ---- ('x', 'd')
# -1.3221475225908594 ---- ('x', 'd')
# -0.34745899102186334 ---- ('x', 'd')
# -1.0434500017467254 ---- ('x', 'd')
# -1.0099418765878465 ---- ('x', 'd')
# -1.8380677677579502 ---- ('x', 'd')
# -0.9387686311201282 ---- ('x', 'd')
# -0.7776194131918178 ---- ('y', 'a')
# -1.0510815639071178 ---- ('y', 'a')
# -0.3675481161171661 ---- ('y', 'a')
# -1.1374596907250272 ---- ('y', 'a')
# -1.3221475225908594 ---- ('y', 'a')
# -0.34745899102186334 ---- ('y', 'a')
# -1.0434500017467254 ---- ('y', 'a')
# -1.0099418765878465 ---- ('y', 'a')
# -1.8380677677579502 ---- ('y', 'a')
# -0.9387686311201282 ---- ('y', 'a')
# -0.7776194131918178 ---- ('y', 'b')
# -1.0510815639071178 ---- ('y', 'b')
# -0.3675481161171661 ---- ('y', 'b')
# -1.1374596907250272 ---- ('y', 'b')
# -1.3221475225908594 ---- ('y', 'b')
# -0.34745899102186334 ---- ('y', 'b')
# -1.0434500017467254 ---- ('y', 'b')
# -1.0099418765878465 ---- ('y', 'b')
# -1.8380677677579502 ---- ('y', 'b')
# -0.9387686311201282 ---- ('y', 'b')
# -0.7776194131918178 ---- ('y', 'c')
# -1.0510815639071178 ---- ('y', 'c')
# -0.3675481161171661 ---- ('y', 'c')
# -1.1374596907250272 ---- ('y', 'c')
# -1.3221475225908594 ---- ('y', 'c')
# -0.34745899102186334 ---- ('y', 'c')
# -1.0434500017467254 ---- ('y', 'c')
# -1.0099418765878465 ---- ('y', 'c')
# -1.8380677677579502 ---- ('y', 'c')
# -0.9387686311201282 ---- ('y', 'c')
# -0.7776194131918178 ---- ('y', 'd')
# -1.0510815639071178 ---- ('y', 'd')
# -0.3675481161171661 ---- ('y', 'd')
# -1.1374596907250272 ---- ('y', 'd')
# -1.3221475225908594 ---- ('y', 'd')
# -0.34745899102186334 ---- ('y', 'd')
# -1.0434500017467254 ---- ('y', 'd')
# -1.0099418765878465 ---- ('y', 'd')
# -1.8380677677579502 ---- ('y', 'd')
# -0.9387686311201282 ---- ('y', 'd')
# -0.7776194131918178 ---- ('z', 'a')
# -1.0510815639071178 ---- ('z', 'a')
# -0.3675481161171661 ---- ('z', 'a')
# -1.1374596907250272 ---- ('z', 'a')
# -1.3221475225908594 ---- ('z', 'a')
# -0.34745899102186334 ---- ('z', 'a')
# -1.0434500017467254 ---- ('z', 'a')
# -1.0099418765878465 ---- ('z', 'a')
# -1.8380677677579502 ---- ('z', 'a')
# -0.9387686311201282 ---- ('z', 'a')
# -0.7776194131918178 ---- ('z', 'b')
# -1.0510815639071178 ---- ('z', 'b')
# -0.3675481161171661 ---- ('z', 'b')
# -1.1374596907250272 ---- ('z', 'b')
# -1.3221475225908594 ---- ('z', 'b')
# -0.34745899102186334 ---- ('z', 'b')
# -1.0434500017467254 ---- ('z', 'b')
# -1.0099418765878465 ---- ('z', 'b')
# -1.8380677677579502 ---- ('z', 'b')
# -0.9387686311201282 ---- ('z', 'b')
# -0.7776194131918178 ---- ('z', 'c')
# -1.0510815639071178 ---- ('z', 'c')
# -0.3675481161171661 ---- ('z', 'c')
# -1.1374596907250272 ---- ('z', 'c')
# -1.3221475225908594 ---- ('z', 'c')
# -0.34745899102186334 ---- ('z', 'c')
# -1.0434500017467254 ---- ('z', 'c')
# -1.0099418765878465 ---- ('z', 'c')
# -1.8380677677579502 ---- ('z', 'c')
# -0.9387686311201282 ---- ('z', 'c')
# -0.7776194131918178 ---- ('z', 'd')
# -1.0510815639071178 ---- ('z', 'd')
# -0.3675481161171661 ---- ('z', 'd')
# -1.1374596907250272 ---- ('z', 'd')
# -1.3221475225908594 ---- ('z', 'd')
# -0.34745899102186334 ---- ('z', 'd')
# -1.0434500017467254 ---- ('z', 'd')
# -1.0099418765878465 ---- ('z', 'd')
# -1.8380677677579502 ---- ('z', 'd')
# -0.9387686311201282 ---- ('z', 'd')
# -0.7776194131918178 ---- ('u', 'a')
# -1.0510815639071178 ---- ('u', 'a')
# -0.3675481161171661 ---- ('u', 'a')
# -1.1374596907250272 ---- ('u', 'a')
# -1.3221475225908594 ---- ('u', 'a')
# -0.34745899102186334 ---- ('u', 'a')
# -1.0434500017467254 ---- ('u', 'a')
# -1.0099418765878465 ---- ('u', 'a')
# -1.8380677677579502 ---- ('u', 'a')
# -0.9387686311201282 ---- ('u', 'a')
# -0.7776194131918178 ---- ('u', 'b')
# -1.0510815639071178 ---- ('u', 'b')
# -0.3675481161171661 ---- ('u', 'b')
# -1.1374596907250272 ---- ('u', 'b')
# -1.3221475225908594 ---- ('u', 'b')
# -0.34745899102186334 ---- ('u', 'b')
# -1.0434500017467254 ---- ('u', 'b')
# -1.0099418765878465 ---- ('u', 'b')
# -1.8380677677579502 ---- ('u', 'b')
# -0.9387686311201282 ---- ('u', 'b')
# -0.7776194131918178 ---- ('u', 'c')
# -1.0510815639071178 ---- ('u', 'c')
# -0.3675481161171661 ---- ('u', 'c')
# -1.1374596907250272 ---- ('u', 'c')
# -1.3221475225908594 ---- ('u', 'c')
# -0.34745899102186334 ---- ('u', 'c')
# -1.0434500017467254 ---- ('u', 'c')
# -1.0099418765878465 ---- ('u', 'c')
# -1.8380677677579502 ---- ('u', 'c')
# -0.9387686311201282 ---- ('u', 'c')
# -0.7776194131918178 ---- ('u', 'd')
# -1.0510815639071178 ---- ('u', 'd')
# -0.3675481161171661 ---- ('u', 'd')
# -1.1374596907250272 ---- ('u', 'd')
# -1.3221475225908594 ---- ('u', 'd')
# -0.34745899102186334 ---- ('u', 'd')
# -1.0434500017467254 ---- ('u', 'd')
# -1.0099418765878465 ---- ('u', 'd')
# -1.8380677677579502 ---- ('u', 'd')
# -0.9387686311201282 ---- ('u', 'd')
# -0.7776194131918178 ---- ('v', 'a')
# -1.0510815639071178 ---- ('v', 'a')
# -0.3675481161171661 ---- ('v', 'a')
# -1.1374596907250272 ---- ('v', 'a')
# -1.3221475225908594 ---- ('v', 'a')
# -0.34745899102186334 ---- ('v', 'a')
# -1.0434500017467254 ---- ('v', 'a')
# -1.0099418765878465 ---- ('v', 'a')
# -1.8380677677579502 ---- ('v', 'a')
# -0.9387686311201282 ---- ('v', 'a')
# -0.7776194131918178 ---- ('v', 'b')
# -1.0510815639071178 ---- ('v', 'b')
# -0.3675481161171661 ---- ('v', 'b')
# -1.1374596907250272 ---- ('v', 'b')
# -1.3221475225908594 ---- ('v', 'b')
# -0.34745899102186334 ---- ('v', 'b')
# -1.0434500017467254 ---- ('v', 'b')
# -1.0099418765878465 ---- ('v', 'b')
# -1.8380677677579502 ---- ('v', 'b')
# -0.9387686311201282 ---- ('v', 'b')
# -0.7776194131918178 ---- ('v', 'c')
# -1.0510815639071178 ---- ('v', 'c')
# -0.3675481161171661 ---- ('v', 'c')
# -1.1374596907250272 ---- ('v', 'c')
# -1.3221475225908594 ---- ('v', 'c')
# -0.34745899102186334 ---- ('v', 'c')
# -1.0434500017467254 ---- ('v', 'c')
# -1.0099418765878465 ---- ('v', 'c')
# -1.8380677677579502 ---- ('v', 'c')
# -0.9387686311201282 ---- ('v', 'c')
# -0.7776194131918178 ---- ('v', 'd')
# -1.0510815639071178 ---- ('v', 'd')
# -0.3675481161171661 ---- ('v', 'd')
# -1.1374596907250272 ---- ('v', 'd')
# -1.3221475225908594 ---- ('v', 'd')
# -0.34745899102186334 ---- ('v', 'd')
# -1.0434500017467254 ---- ('v', 'd')
# -1.0099418765878465 ---- ('v', 'd')
# -1.8380677677579502 ---- ('v', 'd')
# -0.9387686311201282 ---- ('v', 'd')

# %%
k=df<0
for i in k.columns:
    for j in k.index:
        if k[i][j]==True:
            print(i,j)
# Out:
# x b
# x c
# x d
# y b
# z a
# z b
# u b
# u d
# v c
# v d

# %%
d = {'key1':[1,2,3,4,np.nan],"key2":["sudh" ,"kumar" , np.nan,5,6] ,'key3' :[np.nan,np.nan,np.nan,3,8]}
df = pd.DataFrame(d)

# %%
df.dropna()
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=0)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=1)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=2)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %% [markdown]
# - Thresh is nothing but the atleast non-NaN values should avalible to drop it.
# - Require that many non-NA values to say without dropping it.
# - Here 2nd index has droped due to it had min values avaliable less than 2.

# %%
df.dropna(thresh=3) #it only support the 3 value should be non-null.
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3]
# Index: []

# %%
df.dropna(axis=1 , thresh=3)
# Out:
#    key1   key2
# 0   1.0   sudh
# 1   2.0  kumar
# 2   3.0    NaN
# 3   4.0      5
# 4   NaN      6

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.fillna(567)
# Out:
#     key1   key2   key3
# 0    1.0   sudh  567.0
# 1    2.0  kumar  567.0
# 2    3.0    567  567.0
# 3    4.0      5    3.0
# 4  567.0      6    8.0

# %%
df.fillna(value=df['key1'].mean())
# Out:
#    key1   key2  key3
# 0   1.0   sudh   2.5
# 1   2.0  kumar   2.5
# 2   3.0    2.5   2.5
# 3   4.0      5   3.0
# 4   2.5      6   8.0

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
d1 = {'name' :['sudh' , 'visal' , 'umang', 'vishal' ,'umang'],"mail_id" :["sudh@gmail.com", "vishal@gmail.com",'umang@gmail.com','vishal@gmail.com','umang@gmail.com'],
     'salary' :[100,200,500,200,500]}

# %%
df = pd.DataFrame(d1)

# %%
df
# Out:
#      name           mail_id  salary
# 0    sudh    sudh@gmail.com     100
# 1   visal  vishal@gmail.com     200
# 2   umang   umang@gmail.com     500
# 3  vishal  vishal@gmail.com     200
# 4   umang   umang@gmail.com     500

# %%
df.groupby('mail_id').mean()
# Out:
#                   salary
# mail_id
# sudh@gmail.com       100
# umang@gmail.com      500
# vishal@gmail.com     200

# %%
df.groupby('mail_id').sum()
# Out:
#                   salary
# mail_id
# sudh@gmail.com       100
# umang@gmail.com     1000
# vishal@gmail.com     400

# %%
df.groupby('mail_id').size()
# Out:
# mail_id
# sudh@gmail.com      1
# umang@gmail.com     2
# vishal@gmail.com    2
# dtype: int64

# %%
type(df.groupby('mail_id').describe())
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby('mail_id').describe()
# Out:
#                  salary
#                   count   mean  std    min    25%    50%    75%    max
# mail_id
# sudh@gmail.com      1.0  100.0  NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  500.0  0.0  500.0  500.0  500.0  500.0  500.0
# vishal@gmail.com    2.0  200.0  0.0  200.0  200.0  200.0  200.0  200.0

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com']
# Out:
# salary  count      2.0
#         mean     500.0
#         std        0.0
#         min      500.0
#         25%      500.0
#         50%      500.0
#         75%      500.0
#         max      500.0
# Name: umang@gmail.com, dtype: float64

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com']['salary']['mean']
# Out:
# 500.0

# %%
df.groupby('mail_id').describe().T
# Out:
# mail_id       sudh@gmail.com  umang@gmail.com  vishal@gmail.com
# salary count             1.0              2.0               2.0
#        mean            100.0            500.0             200.0
#        std               NaN              0.0               0.0
#        min             100.0            500.0             200.0
#        25%             100.0            500.0             200.0
#        50%             100.0            500.0             200.0
#        75%             100.0            500.0             200.0
#        max             100.0            500.0             200.0

# %%
df.groupby('mail_id').describe()
# Out:
#                  salary
#                   count   mean  std    min    25%    50%    75%    max
# mail_id
# sudh@gmail.com      1.0  100.0  NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  500.0  0.0  500.0  500.0  500.0  500.0  500.0
# vishal@gmail.com    2.0  200.0  0.0  200.0  200.0  200.0  200.0  200.0

# %%
arr1 = np.random.randn(3,4)
arr2 = np.random.randn(3,4)
arr3 = np.random.randn(3,4)

# %%
df1 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])
df2 = pd.DataFrame(arr2,columns=["A","B","C","D"],index = [3,4,5])

# %%
df2
# Out:
#           A         B         C         D
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620

# %%
df3 = pd.DataFrame(arr3,columns=["A","B","C","D"],index = [6,7,8])

# %%
df1
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711

# %%
df2
# Out:
#           A         B         C         D
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620

# %%
df3
# Out:
#           A         B         C         D
# 6 -0.071324 -0.045438  1.040886 -0.094035
# 7 -0.420844 -0.551989 -0.121098  0.190141
# 8  0.512137  0.131538 -0.331617 -1.632386

# %%
df4 = pd.concat([df1,df2,df3])

# %%
df5 = pd.concat([df1,df2,df3],axis=1)

# %%
df4
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620
# 6 -0.071324 -0.045438  1.040886 -0.094035
# 7 -0.420844 -0.551989 -0.121098  0.190141
# 8  0.512137  0.131538 -0.331617 -1.632386

# %%
df4.iloc[0]
# Out:
# A   -0.201841
# B    1.045371
# C    0.538162
# D    0.812119
# Name: 0, dtype: float64

# %%
df4.loc[0]
# Out:
# A   -0.201841
# B    1.045371
# C    0.538162
# D    0.812119
# Name: 0, dtype: float64

# %%
df5
# Out:
#           A         B         C         D         A         B         C  \
# 0 -0.201841  1.045371  0.538162  0.812119       NaN       NaN       NaN
# 1  0.241106 -0.952510 -0.136267  1.267248       NaN       NaN       NaN
# 2  0.173634 -1.223255  1.415320  0.457711       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN  0.728876  1.968435 -0.547788
# 4       NaN       NaN       NaN       NaN -2.506230  0.146960  0.606195
# 5       NaN       NaN       NaN       NaN  0.013422  0.935945  0.420623
# 6       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           D         A         B         C         D
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# 3 -0.679418       NaN       NaN       NaN       NaN
# 4 -0.022539       NaN       NaN       NaN       NaN
# 5  0.411620       NaN       NaN       NaN       NaN
# 6       NaN -0.071324 -0.045438  1.040886 -0.094035
# 7       NaN -0.420844 -0.551989 -0.121098  0.190141
# 8       NaN  0.512137  0.131538 -0.331617 -1.632386

# %%
df5['A']
# Out:
#           A         A         A
# 0 -0.201841       NaN       NaN
# 1  0.241106       NaN       NaN
# 2  0.173634       NaN       NaN
# 3       NaN  0.728876       NaN
# 4       NaN -2.506230       NaN
# 5       NaN  0.013422       NaN
# 6       NaN       NaN -0.071324
# 7       NaN       NaN -0.420844
# 8       NaN       NaN  0.512137

# %%
df5.iloc[:,4]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3    0.728876
# 4   -2.506230
# 5    0.013422
# 6         NaN
# 7         NaN
# 8         NaN
# Name: A, dtype: float64

# %%
pd.concat([df1,df2,df3],axis=1).fillna(0)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -0.201841  1.045371  0.538162  0.812119  0.000000  0.000000  0.000000
# 1  0.241106 -0.952510 -0.136267  1.267248  0.000000  0.000000  0.000000
# 2  0.173634 -1.223255  1.415320  0.457711  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.728876  1.968435 -0.547788
# 4  0.000000  0.000000  0.000000  0.000000 -2.506230  0.146960  0.606195
# 5  0.000000  0.000000  0.000000  0.000000  0.013422  0.935945  0.420623
# 6  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           D         A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000
# 3 -0.679418  0.000000  0.000000  0.000000  0.000000
# 4 -0.022539  0.000000  0.000000  0.000000  0.000000
# 5  0.411620  0.000000  0.000000  0.000000  0.000000
# 6  0.000000 -0.071324 -0.045438  1.040886 -0.094035
# 7  0.000000 -0.420844 -0.551989 -0.121098  0.190141
# 8  0.000000  0.512137  0.131538 -0.331617 -1.632386

# %%
df1
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711

# %%
df2
# Out:
#           A         B         C         D
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620

# %%
np.random.seed(23)
arr1 = np.random.randn(3,4)
np.random.seed(23)
arr2 = np.random.randn(3,4)
df11 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])
df22 = pd.DataFrame(arr2,columns=["A","B","C","D"],index = [3,4,5])

# %%
df11
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
df22
# Out:
#           A         B         C         D
# 3  0.666988  0.025813 -0.777619  0.948634
# 4  0.701672 -1.051082 -0.367548 -1.137460
# 5 -1.322148  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df22,on= "A")
# Out:
#           A       B_x       C_x       D_x       B_y       C_y       D_y
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140  1.772258 -0.347459  0.670140

# %%
df1 = pd.DataFrame({'key': ['K0', 'K8', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})

df2 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K8  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
df2
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %% [markdown]
# Whenever we find the same column name on that we have to merge the two or more DataFrame.

# %%
pd.merge(df1,df2,on= 'key',how = 'outer')
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K8   A1   B1  NaN  NaN
# 2  K2   A2   B2   C2   D2
# 3  K3   A3   B3   C3   D3
# 4  K1  NaN  NaN   C1   D1

# %%
import pandas as pd
df1 = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
df2 = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
df2
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(df1,df2,on = ['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

df2 = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
df1
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
df2
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
df1.join(df2,how = 'left')
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
df1.join(df2,how = 'outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# Merge and columns are both are the same
# - Merge work on the columns similarity.
# - Join work on the row similarity.

# %%
df1.join(df2,how='right')
# Out:
#       A    B   C   D
# K0   A0   B0  C0  D0
# K2   A2   B2  C2  D2
# K3  NaN  NaN  C3  D3

# %%
df1.join(df2,how='inner')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2
