# %% [markdown]
# ## Pandas

# %% [markdown]
# - Pandas is an open source Python package that is most widely used for data science/data analysis and machine learning tasks. It is built on top of another package named Numpy, which provides support for multi-dimensional arrays. As one of the most popular data wrangling packages, Pandas works well with many other data science modules inside the Python ecosystem, and is typically included in every Python distribution, from those that come with your operating system to commercial vendor distributions like ActiveState’s ActivePython.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Data Reading Operation

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('cricket_data.csv',nrows=1000)

# %%
pd.set_option("max_columns",None)

# %%
data.head()
# Out:
#        ID              NAME  COUNTRY                       Full name  \
# 0    8772      Henry Arkell  England        Henry John Denham Arkell
# 1  532565     Richard Nyren  England                   Richard Nyren
# 2   16856  Sydney Maartensz  England  Sydney Gratien Adair Maartensz
# 3   16715      Brian Lander  England            Brian Richard Lander
# 4   15989  Derek Kenderdine  England        Derek Charles Kenderdine
#
#                                              Born  \
# 0           \nJune 26, 1898, Edmonton, Middlesex
# 1              \nApril 25, 1734, Eartham, Sussex
# 2              \nApril 14, 1882, Colombo, Ceylon
# 3  \nJanuary 9, 1942, Bishop Auckland, Co Durham
# 4          \nOctober 28, 1897, Chislehurst, Kent
#
#                                                 Died       Current age  \
# 0   March 12, 1982, Oxford (aged 83 years 259 days)                NaN
# 1  April 25, 1797, Lee or Leigh, Kent (aged 63 ye...               NaN
# ...

# %%
data.tail()
# Out:
#           ID              NAME  COUNTRY                 Full name  \
# 995   566019        Max Morley  England           Max Gary Morley
# 996   874221  Katherine Morley  England  Katherine Frances Morley
# 997  1095848      Kathy Morley  England              Kathy Morley
# 998    17914       John Morley  England          John Wiby Morley
# 999  1147569       Jack Morley  England             Jack P Morley
#
#                                              Born  \
# 995  \nJanuary 24, 1993, Huddersfield, Yorkshire
# 996                   \nJune 10, 1999, Cambridge
# 997                               \ndate unknown
# 998       \nJuly 30, 1838, Raithby, Lincolnshire
# 999                               \ndate unknown
#
#                                                   Died        Current age  \
# 995                                                NaN   26 years 58 days
# 996                                                NaN  19 years 286 days
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### In order to save the desirable file.

# %%
data1=data.head()

# %%
data1.to_csv('New_data.csv')

# %%
pwd()
# Out:
# 'F:\\Programming\\Full Stack Data Science\\Python Programming Language\\Python Libraries\\Pandas'

# %%
# !dir
# Out:
#  Volume in drive F is New Volume
#  Volume Serial Number is 8E82-72AA
#
#  Directory of F:\Programming\Full Stack Data Science\Python Programming Language\Python Libraries\Pandas
#
# 28/06/2021  12:46 PM    <DIR>          .
# 28/06/2021  12:46 PM    <DIR>          ..
# 28/06/2021  12:20 PM    <DIR>          .ipynb_checkpoints
# 28/06/2021  12:28 PM        43,890,380 cricket_data.csv
# 28/06/2021  12:47 PM             5,267 New_data.csv
# 28/06/2021  12:46 PM           204,683 Pandas Lecture  1.ipynb
#                3 File(s)     44,100,330 bytes
#                3 Dir(s)  376,671,358,976 bytes free

# %% [markdown]
# From that we can see,there is `New_data.csv` file is avaliable.

# %%
data2 = pd.read_csv('New_data.csv')
data2
# Out:
#    Unnamed: 0      ID              NAME  COUNTRY  \
# 0           0    8772      Henry Arkell  England
# 1           1  532565     Richard Nyren  England
# 2           2   16856  Sydney Maartensz  England
# 3           3   16715      Brian Lander  England
# 4           4   15989  Derek Kenderdine  England
#
#                         Full name  \
# 0        Henry John Denham Arkell
# 1                   Richard Nyren
# 2  Sydney Gratien Adair Maartensz
# 3            Brian Richard Lander
# 4        Derek Charles Kenderdine
#
#                                              Born  \
# 0           \nJune 26, 1898, Edmonton, Middlesex
# 1              \nApril 25, 1734, Eartham, Sussex
# 2              \nApril 14, 1882, Colombo, Ceylon
# 3  \nJanuary 9, 1942, Bishop Auckland, Co Durham
# 4          \nOctober 28, 1897, Chislehurst, Kent
#
#                                                 Died       Current age  \
# 0   March 12, 1982, Oxford (aged 83 years 259 days)                NaN
# ...

# %% [markdown]
# ### Seperator in data and read with pandas

# %%
data = pd.read_csv("Data1.csv") #sep =" " is use whenver file is seperated by some charecter.

# %% [markdown]
# ### Data header we dont want.

# %%
data = pd.read_csv("Data1.csv",header=None)

# %%
data =data.iloc[:,:5]

# %%
data.to_csv('Data.csv')

# %%
new = pd.read_csv('Data.csv',header=None,names=['A','B','C','D','E'])
new
# Out:
#        A       B                 C        D                               E
# NaN  0.0       1                 2        3                               4
# 0.0  NaN      ID              NAME  COUNTRY                       Full name
# 1.0  0.0    8772      Henry Arkell  England        Henry John Denham Arkell
# 2.0  1.0  532565     Richard Nyren  England                   Richard Nyren
# 3.0  2.0   16856  Sydney Maartensz  England  Sydney Gratien Adair Maartensz
# 4.0  3.0   16715      Brian Lander  England            Brian Richard Lander
# 5.0  4.0   15989  Derek Kenderdine  England        Derek Charles Kenderdine

# %% [markdown]
# ## SkipRows

# %%
new = pd.read_csv('Data.csv',header=None,names=['A','B','C','D','E'],skiprows=[0])
new
# Out:
#      A       B                 C        D                               E
# 0  NaN      ID              NAME  COUNTRY                       Full name
# 1  0.0    8772      Henry Arkell  England        Henry John Denham Arkell
# 2  1.0  532565     Richard Nyren  England                   Richard Nyren
# 3  2.0   16856  Sydney Maartensz  England  Sydney Gratien Adair Maartensz
# 4  3.0   16715      Brian Lander  England            Brian Richard Lander
# 5  4.0   15989  Derek Kenderdine  England        Derek Charles Kenderdine

# %% [markdown]
# ### Na_values
#
# It is going fill na values as our give content.

# %%
new = pd.read_csv('Data.csv',header=None,names=['A','B','C','D','E'],na_values=['Henry Arkell'])
new
# Out:
#        A       B                 C        D                               E
# NaN  0.0       1                 2        3                               4
# 0.0  NaN      ID              NAME  COUNTRY                       Full name
# 1.0  0.0    8772               NaN  England        Henry John Denham Arkell
# 2.0  1.0  532565     Richard Nyren  England                   Richard Nyren
# 3.0  2.0   16856  Sydney Maartensz  England  Sydney Gratien Adair Maartensz
# 4.0  3.0   16715      Brian Lander  England            Brian Richard Lander
# 5.0  4.0   15989  Derek Kenderdine  England        Derek Charles Kenderdine

# %% [markdown]
# ### Data Type Checking

# %%
new.dtypes
# Out:
# A    float64
# B     object
# C     object
# D     object
# E     object
# dtype: object

# %% [markdown]
# ### Data  Describe

# %% [markdown]
# - In order to get the data which is in the form of numerical data.
# - In count we will get the records of each column that contains the values.
# - Mean means its average.
# - Standard Deviation means the how much value away from the mean.
# - Min and max is nothing but the which value is maximum and minimum respctively.

# %%
round(new.describe(),2)
# Out:
#           A
# count  6.00
# mean   1.67
# std    1.63
# min    0.00
# 25%    0.25
# 50%    1.50
# 75%    2.75
# max    4.00

# %% [markdown]
# - In all condition the data will get automatically sorted.
# - `25%`:- Data we will get at 25% of index position
# - `50%`:- Data we will get at 50% of index position
# - `75%`:-Data we will get at 75% of index position

# %% [markdown]
# ### .to_csv()

# %%
new.to_csv("index.csv",index=False) #it remove the index column

# %%
new.to_csv("index1.csv",index=False,header=False,sep="#",columns=['A','B','C'])

# %% [markdown]
# ### How to fetch the columns from dataframe.

# %%
new.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
new[['A','B','C']]
# Out:
#        A       B                 C
# NaN  0.0       1                 2
# 0.0  NaN      ID              NAME
# 1.0  0.0    8772               NaN
# 2.0  1.0  532565     Richard Nyren
# 3.0  2.0   16856  Sydney Maartensz
# 4.0  3.0   16715      Brian Lander
# 5.0  4.0   15989  Derek Kenderdine

# %%
new['A']
# Out:
# NaN    0.0
# 0.0    NaN
# 1.0    0.0
# 2.0    1.0
# 3.0    2.0
# 4.0    3.0
# 5.0    4.0
# Name: A, dtype: float64

# %%
type(new['A'])
# Out:
# pandas.core.series.Series

# %%
type(new[['A']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### .read_html

# %%
df1 =pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool')

# %%
type(df1)
# Out:
# list

# %%
df1[0]
# Out:
#        Season   Age                                   Team  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %% [markdown]
# ### Export the data from GitHUB

# %%
Data = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv',error_bad_lines=False)
Data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### read json file.

# %%
import json

# %%
s = """
    { "Name":["Roshan","Raju","Rajesh"],
    
    "Phone_number":[2455667],
    
    "Company":["EY","Bajaj","Tech M","B Finace"]
}

"""

# %%
s1=json.loads(s)
s1
# Out:
# {'Name': ['Roshan', 'Raju', 'Rajesh'],
#  'Phone_number': [2455667],
#  'Company': ['EY', 'Bajaj', 'Tech M', 'B Finace']}

# %%
df = pd.DataFrame.from_dict(s1, orient='index')
df = df.transpose()
df
# Out:
#      Name Phone_number   Company
# 0  Roshan      2455667        EY
# 1    Raju         None     Bajaj
# 2  Rajesh         None    Tech M
# 3    None         None  B Finace

# %% [markdown]
# ### Complex Json File.

# %%
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42277',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42277/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42277/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42277/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42277',
#   'id': 931314032,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njc4ODI4MzA5',
#   'number': 42277,
#   'title': 'DOC GH29075 close database connections after creation',
#   'user': {'login': 'TAJD',
#    'id': 11210290,
#    'node_id': 'MDQ6VXNlcjExMjEwMjkw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11210290?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TAJD',
#    'html_url': 'https://github.com/TAJD',
# ...

# %% [markdown]
# In order to chek wheather it is good json file or not
#
# Link :- **http://jsonviewer.stack.hu/**

# %%
js[0]['title']
# Out:
# 'DOC GH29075 close database connections after creation'

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# DOC GH29075 close database connections after creation
# BUG: `Styler.to_excel` does not export styles and formats correctly
# ENH: groupby.max() should not cast int to int64 but keep original data type
# ⬆️ UPGRADE: Autoupdate pre-commit config
# ENH: Add `method='table'` for EWM.mean
# BUG: false negatives for multiindex joins validation
# CLN: simplify Styler clear mechanics and tests
# PERF: CategoricalIndex.get_indexer
# DEPR: Index.get_loc with method
# PERF: IntervalIndex.intersection
# TST IntegerArray bounds error closing GH21796
# BUG: Series.loc[dtstr] type depends on monotonicity
# CLN: Group tests for apply/agg/transform with a string argument
# CLN: simplify take2d_axis0 generated code
# BUG: Fix to_datetime() cache behaviour to not omit duplicated output values
# CLN: allow label memviews to be None
# BUG: With cache, to_datetime() returns pd.NaT for inputs that produce duplicated values
# REF: simplify __can_partial_date_slice, _parsed_string_to_bounds
# ...

# %%
len(js)
# Out:
# 30

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42277',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42277/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42277/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42277/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42277',
#   'id': 931314032,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njc4ODI4MzA5',
#   'number': 42277,
#   'title': 'DOC GH29075 close database connections after creation',
#   'user': {'login': 'TAJD',
#    'id': 11210290,
#    'node_id': 'MDQ6VXNlcjExMjEwMjkw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11210290?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TAJD',
#    'html_url': 'https://github.com/TAJD',
# ...

# %%
pd.DataFrame(js,columns=['url','title']).head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                title
# 0  DOC GH29075 close database connections after c...
# 1  BUG: `Styler.to_excel` does not export styles ...
# 2  ENH: groupby.max() should not cast int to int6...
# 3           ⬆️ UPGRADE: Autoupdate pre-commit config
# 4             ENH: Add `method='table'` for EWM.mean

# %%
df4 =pd.DataFrame(js).head().head()
df4
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
df4.to_csv("json_dump.csv")

# %%
type(js)
# Out:
# list

# %%
js[0]['user']
# Out:
# {'login': 'TAJD',
#  'id': 11210290,
#  'node_id': 'MDQ6VXNlcjExMjEwMjkw',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/11210290?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/TAJD',
#  'html_url': 'https://github.com/TAJD',
#  'followers_url': 'https://api.github.com/users/TAJD/followers',
#  'following_url': 'https://api.github.com/users/TAJD/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/TAJD/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/TAJD/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/TAJD/subscriptions',
#  'organizations_url': 'https://api.github.com/users/TAJD/orgs',
#  'repos_url': 'https://api.github.com/users/TAJD/repos',
#  'events_url': 'https://api.github.com/users/TAJD/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/TAJD/received_events',
#  'type': 'User',
#  'site_admin': False}

# %% [markdown]
# ### Task :-

# %%
lst = []
for i in range(len(df4.columns)):
    lst.append(js[i]['user'])
pd.DataFrame(lst)
# Out:
#                   login        id               node_id  \
# 0                  TAJD  11210290  MDQ6VXNlcjExMjEwMjkw
# 1              attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 2        rd-andreas-lay  67090720  MDQ6VXNlcjY3MDkwNzIw
# 3   github-actions[bot]  41898282  MDM6Qm90NDE4OTgyODI=
# 4             mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5               cf-vrgl  82909524  MDQ6VXNlcjgyOTA5NTI0
# 6              attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 7          jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 8          jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 9          jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 10                 TAJD  11210290  MDQ6VXNlcjExMjEwMjkw
# 11         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 12           rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 13           mzeitlin11  37011898  MDQ6VXNlcjM3MDExODk4
# 14                zyc09  56645775  MDQ6VXNlcjU2NjQ1Nzc1
# 15           mzeitlin11  37011898  MDQ6VXNlcjM3MDExODk4
# ...

# %%
json_data = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
data = pd.DataFrame.from_records(json_data['user'])
data.head()
# Out:
#                  login        id               node_id  \
# 0                 TAJD  11210290  MDQ6VXNlcjExMjEwMjkw
# 1             attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 2       rd-andreas-lay  67090720  MDQ6VXNlcjY3MDkwNzIw
# 3  github-actions[bot]  41898282  MDM6Qm90NDE4OTgyODI=
# 4            mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/112102...
# 1  https://avatars.githubusercontent.com/u/242565...
# 2  https://avatars.githubusercontent.com/u/670907...
# 3  https://avatars.githubusercontent.com/in/15368...
# 4  https://avatars.githubusercontent.com/u/106470...
#
#                                                  url  \
# 0                  https://api.github.com/users/TAJD
# 1              https://api.github.com/users/attack68
# 2        https://api.github.com/users/rd-andreas-lay
# 3  https://api.github.com/users/github-actions%5B...
# ...

# %% [markdown]
# ### Thanks !!
