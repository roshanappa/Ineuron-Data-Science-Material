# %%
import numpy as np
import pandas as pd

# %%
data = pd.DataFrame(np.arange(1,31).reshape(6,5),index=[[1,2,2,3,3,3],['monday','monday','tuesday','monday','tuesday','wednessday']],columns=[['Boys','Boys','Girls','Girls','Teacher'],['Present','Absent','Present','Absent','No Worries']])

# %%
data
# Out:
#                 Boys          Girls           Teacher
#              Present Absent Present Absent No Worries
# 1 monday           1      2       3      4          5
# 2 monday           6      7       8      9         10
#   tuesday         11     12      13     14         15
# 3 monday          16     17      18     19         20
#   tuesday         21     22      23     24         25
#   wednessday      26     27      28     29         30

# %%
data.columns
# Out:
# MultiIndex([(   'Boys',    'Present'),
#             (   'Boys',     'Absent'),
#             (  'Girls',    'Present'),
#             (  'Girls',     'Absent'),
#             ('Teacher', 'No Worries')],
#            )

# %%
data.index
# Out:
# MultiIndex([(1,     'monday'),
#             (2,     'monday'),
#             (2,    'tuesday'),
#             (3,     'monday'),
#             (3,    'tuesday'),
#             (3, 'wednessday')],
#            )

# %%
data[0:3]
# Out:
#              Boys          Girls           Teacher
#           Present Absent Present Absent No Worries
# 1 monday        1      2       3      4          5
# 2 monday        6      7       8      9         10
#   tuesday      11     12      13     14         15

# %%
data[:]
# Out:
#                 Boys          Girls           Teacher
#              Present Absent Present Absent No Worries
# 1 monday           1      2       3      4          5
# 2 monday           6      7       8      9         10
#   tuesday         11     12      13     14         15
# 3 monday          16     17      18     19         20
#   tuesday         21     22      23     24         25
#   wednessday      26     27      28     29         30

# %%
data[0:1]
# Out:
#             Boys          Girls           Teacher
#          Present Absent Present Absent No Worries
# 1 monday       1      2       3      4          5

# %%
data[3:]
# Out:
#                 Boys          Girls           Teacher
#              Present Absent Present Absent No Worries
# 3 monday          16     17      18     19         20
#   tuesday         21     22      23     24         25
#   wednessday      26     27      28     29         30

# %%
data.iloc[:,:3]
# Out:
#                 Boys          Girls
#              Present Absent Present
# 1 monday           1      2       3
# 2 monday           6      7       8
#   tuesday         11     12      13
# 3 monday          16     17      18
#   tuesday         21     22      23
#   wednessday      26     27      28

# %%
data.iloc[:5,:3]
# Out:
#              Boys          Girls
#           Present Absent Present
# 1 monday        1      2       3
# 2 monday        6      7       8
#   tuesday      11     12      13
# 3 monday       16     17      18
#   tuesday      21     22      23

# %%
data.iloc[1:3,:4]
# Out:
#              Boys          Girls
#           Present Absent Present Absent
# 2 monday        6      7       8      9
#   tuesday      11     12      13     14

# %%
data.loc[(1,'monday'),('Teacher','No Worries')]
# Out:
# 5
