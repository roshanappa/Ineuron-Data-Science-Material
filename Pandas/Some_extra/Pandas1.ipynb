# %%
#pandas
#it can process any type of the data,statactical analysis,cleaning of the data files like removing missing value,outlier,filtring
#rows and columns by some criteria by appling arthematical,logical mathematical function,we can use it for the data visualiation with the 
#help of matplotlib liberary,using  lines bars,histogram plot,line plot,plotbars ,bubble plot,plot bars,bar plot and other kind of plots.
#after the cleaning data we have to transform the data and then finally we can right back into a csv file #press H to get the shortcut of jupyter notebook
import pandas as pd
#[shift+Enter]
#after press the . we need press the tab see the curnal will busy
#core component i.e.series and DataFrame

# %%
data = { 'apple' : [23,34,87,78],'mangoes' :[34,87,98,55]}
print(data)
# Out:
# {'apple': [23, 34, 87, 78], 'mangoes': [34, 87, 98, 55]}

# %%
type(data)
# Out:
# dict

# %%
#dataframe
df = pd.DataFrame(data)
print(df)
# Out:
#    apple  mangoes
# 0     23       34
# 1     34       87
# 2     87       98
# 3     78       55

# %%
#series
print('#this is about the "apple" series')
print(df['apple'])
print('#this is about the "mangoes" series')
print(df['mangoes'])
# Out:
# #this is about the "apple" series
# 0    23
# 1    34
# 2    87
# 3    78
# Name: apple, dtype: int64
# #this is about the "mangoes" series
# 0    34
# 1    87
# 2    98
# 3    55
# Name: mangoes, dtype: int64

# %%
print(type(df['apple']))
print('# point to be remember if we have have the two column that time  called as "datafram" if we have the single coumn that it called as "series"')
# Out:
# <class 'pandas.core.series.Series'>
# # point to be remember if we have have the two column that time  called as "datafram" if we have the single coumn that it called as "series"

# %%
#how to read the .csv files
#press the tab after the '.' it will to get the suggestion wich method you waant if we see that kernal busy that time
datafm = pd.read_csv('nba.csv')
print(datafm)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# head is noting but abtracting the intial data that will start form the bigining of dataframe that will be n=5
#if we want to know then press the shift+tab in datafm.head(shift+tab) then we will see
#if we want the more info (documentation about the head function )that time we need to press shift+double tab e.g.datafm.head(shift+press the tab 2 times)
datafm.head
#this is how we can do it
# Out:
# <bound method NDFrame.head of               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# ...

# %%
print('but if we wanted to get the specific observation from the head postion so for that we need to sepecify it like below')
datafm.head(1)
# Out:
# but if we wanted to get the specific observation from the head postion so for that we need to sepecify it like below
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %%
datafm.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
datafm.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
#if we want to print the last ten rows that time we have to use the function that is tail it will give the last 5 row by default
#if we want the deatils about the tailfunction press(shift+2tab) and if we want to know about the default value then press(shift+tab)
datafm.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
datafm.tail(1)
# Out:
#     Name Team  Number Position  Age Height  Weight College  Salary
# 457  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN

# %%
datafm.tail(2)
# Out:
#             Name       Team  Number Position   Age Height  Weight College  \
# 456  Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457          NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#        Salary
# 456  947276.0
# 457       NaN

# %%
datafm.tail(10)
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 450      Joe Ingles  Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454       Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455    Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0
# 456     Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0
# 457             NaN        NaN     NaN      NaN   NaN    NaN     NaN
#
#       College      Salary
# 448    Butler  15409570.0
# 449      Duke   1348440.0
# 450       NaN   2050000.0
# 451    Dayton    981348.0
# 452  Kentucky   2239800.0
# 453    Butler   2433333.0
# ...

# %%
datafm.tail(0)
#it won't print
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
#if we see the upper datafram in that we are getting by default index but dont want it we want the name at the postion of index column that we need to take the help of the following method.
#datafm= pd.read_csv('nbd.cvs' ,shft+2tab ) then we see the multiple method but we choose the index.col=name
#in this method we had replaces the index column wilth the name of other column there we nedd to write particular column as 'Name' 
datafm = pd.read_csv('nba.csv' , index_col ='Name')
print(datafm)
#now we see the name got the column of index
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
datafm = pd.read_csv('nba.csv')
datafm = pd.read_csv('nba.csv' , index_col ='Name')
datafm.head()
#print('#in this way we can can replace index column with any column simply we have to write down the name of the particaticular column name at position of name')
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0
