# %% [markdown]
# ## Object Oriented Programming Language.

# %% [markdown]
# - Object-Oriented Programming makes the program easy to understand as well as efficient. Since the class is sharable, the code can be reused. Data is safe and secure with data abstraction. Polymorphism allows the same interface for different objects, so programmers can write efficient code
# - Python is a multi-paradigm programming language. It supports different programming approaches.
# - One of the popular approaches to solve a programming problem is by creating objects. This is known as Object-Oriented Programming (OOP).
# - An object has two characteristics:
#  - **Attributes**
#  - **Behavior**
# - A parrot is an object, as it has the following properties:
#  -  **name, age, color as attributes**
#  -  **singing, dancing as behavior**
# - The concept of OOP in Python focuses on creating reusable code. This concept is also known as DRY (Don't Repeat Yourself).

# %% [markdown]
# ## Inside the Object Oriented Language
#
# We have there major terms like below way
#
# - **Class**
# - **Method**
# - **Object**

# %% [markdown]
# ## Classes

# %% [markdown]
# - A class is a blueprint for the object.
#
# - We can think of **class** as a sketch of a parrot with labels.
# - It contains all the details about the name, colors, size etc. Based on these descriptions, we can study about the parrot. Here, a parrot is an object.
# - Inside the class we have  features or entity on similar interest.Like animal class and inside this class we have cow,buffelow,got etc are the oject.

# %%
A = 10
B = "String"

# %% [markdown]
# Here we can say the variable name with `"A"` and `"B"` are the oject or class `"int"` and `"string"` respectively.

# %%
class Parrot:
    pass

# %% [markdown]
# Here, we use the class keyword to define an empty class Parrot. From class, we construct instances. An instance is a specific object created from a particular class.

# %% [markdown]
# The class can be defined as a collection of objects. It is a logical entity that has some specific attributes and methods. For example: if you have an employee class, then it should contain an attribute and method, i.e. an email id, name, age, salary, etc.

# %% [markdown]
# ## Methods

# %% [markdown]
# - A method in object-oriented programming (OOP) is a procedure associated with a message and an object.
# - Data is represented as properties of the object, and behaviors are represented as methods. For example, a Window object could have methods such as open and close, while its state (whether it is open or closed at any given point in time) would be a property.
# - In class-based programming, methods are defined within a class, and objects are instances of a given class.

# %% [markdown]
# - In the simple laguage the function inside the OOP language is called as method.
# - Inside the OOPs concept the methods having certain behaviour.
# - The method is a function that is associated with an object. In Python, a method is not unique to class instances. Any object type can have methods.

# %% [markdown]
# ## Objects

# %% [markdown]
# - Class is nothing but the real world entity and it's attribute are called as objects.
# - The object is an entity that has state and behavior. It may be any real-world object like the mouse, keyboard, chair, table, pen, etc.
# - Everything in Python is an object, and almost everything has attributes and methods.

# %%
class car:   #class
    def __init__(self,modelname, year):  #init method for the allocation of the memory #method
        self.modelname = modelname  #class atribute
        self.year = year  
    def display(self):         #method
        print(self.modelname,self.year)  
  
c1 = car("Toyota", 2016)  #object
c1.display()  #object by its method.
# Out:
# Toyota 2016

# %% [markdown]
# - In the above example, we have created the class named car, and it has two attributes modelname and year.
# - We have created a **c1 object** to access the class attribute.
# - The **c1 object** will allocate memory for these values.

# %% [markdown]
# ### Example 1.

# %%
class car:
    pass

# %%
audi = car()

# %%
audi.model = "A22"
audi.year = 2020
audi.engine = 4
audi.millege = 120

# %%
print(audi.millege,audi.year)
# Out:
# 120 2020

# %%
nano = car()

# %%
nano.model = "A2"
nano.year = 2021
nano.engine = 8
nano.millege = 180

# %%
print(nano.millege,nano.year)
# Out:
# 180 2021

# %% [markdown]
# - In the above we can write the code but this not the good practice at all.
# - There we have to write the code again and again for assigning the attribute to each object of class.
# - As the objet will get increase this operation will be increase as well.

# %% [markdown]
# ### Example 2

# %% [markdown]
# - From the below class,we can see that we have done code reusability in nice way.
# - In that we can see that we have use method which can work like contructor in python.
# - It is helping us allocate the memory to each argument inside the class.
# - **`self`** is the keyword that is going to refer the which class object we going to use.
# - Like **`car1`** and **`car2`** are two kinds of objects and each having the different information.
# - iniit method help to get the information according our class input attribute that we need pass.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class car:
    
    def __init__(self,millege,model,year,engine): #init method with an argument
        self.millege = millege    #assignment of values to that arguments
        self.model = model
        self.year = year
        self.engine = engine

        
car1 = car(120,"A2",2007,"V4")
car2  = car(222,"D4",2011,"V2")

# %%
print(car1.millege,car2.millege)
# Out:
# 120 222

# %%
print(car1.model,car2.model)
# Out:
# A2 D4

# %% [markdown]
# ### Self

# %% [markdown]
# Inside the any method our first attribute will behave like **`self`**.

# %%
class car:
    
    def __init__(millege,model,year,engine): #init method with an argument
        millege.millege = millege    #assignment of argument values to class variable
        millege.model = model
        millege.year = year
        millege.engine = engine

# %% [markdown]
# Here,in this case **`Millege`** will behave like **`self`**.

# %% [markdown]
# - As we can see that,input data inside the class in going to be use in right hand side of init method.
# - In the left hand side we have bounded the self variable that is class variable made for each attribute.
# - Self is refering the object of class
# - There is object is self.cpu and self.ram for attributes cpu and ram respectively.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So from the below we can understand that class attribute variable for any attribute will be avalible in any text form means it is not mendatory to have name of attribute as similar as name of class attribute variable.

# %%
class car:
    
    def __init__(self,m,mo,y,eng): #init method with an argument
        self.millege = m     #assignment of argument values to class attribute variable
        self.model = mo
        self.year = y
        self.engine = eng
        
car1 = car(111,"ddd",2021,'V')
car1.millege  #m is the just placeholder there our input will get store
#class attribute varible will be useful to extarct any data.
# Out:
# 111

# %% [markdown]
# #### self can be change locally inside the class but throghout any particular function self name should be same.

# %%
class car:
    
    def __init__(a,model,year,engine,): #init method with an argument
        
        a.model = model #assignment of argument values to class variable
        a.year = year
        a.engine = engine
    
    def age(b,current_year):#self can be change locally inside the class but throghout any 
                                                    #particular function self name should be same.
            return current_year - b.year
    
    def engine1(self):
        return print('This is our millege :-',self.engine)
    
    
car1 = car("ddd",2018,'V')
car1.age(2021)
# Out:
# 3

# %%
car1.engine1()
# Out:
# This is our millege :- V

# %% [markdown]
# #### For getting string whenever we will print the class.

# %%
class car:
    
    def __init__(a,model,year,engine,):
        
        a.model = model
        a.year = year
        a.engine = engine
    
    def age(b,current_year):
            return current_year - b.year
    
    def engine1(self):
        return print('This is our millege :-',self.engine)
    
    def __str__(c):
        return "This is my car that I have created."

# %%
car1 = car(123,2011,'V1')

# %%
car1.model
# Out:
# 123

# %%
car1  #I will get the address of that class.

# %%
print(car1)
# Out:
# This is my car that I have created.

# %% [markdown]
# ### Example 3

# %%
class Student:
    def __init__(self,name,rollno,joining_date,current_topic):
        self.name = name
        self.rollno = rollno
        self.joining_date = joining_date
        self.current_topic = current_topic
        
    def name_parsering(self):
        if type(self.name)==list:
            for i in self.name:
                print(i)
        else:
            print('Provided list is not in the form of list.')
    def cr_topic(self):
        return print("This is your current topic :- ",self.current_topic)
    
    try:
        def str_rollno(self):
            if type(self.rollno)==str:
                print("Don't do anything.")
            else:
                return str(self.rollno)
    except Exception as e:
        print('This is the error msg',e)
        
    
    def duration(self,current_date):
        return print("This is yoour durartion :-",current_date - self.joining_date)
    
    def __str__(self):
        return "This is the student class where they can tried to input there own data and they can try to fetch it."

# %%
Roshan = Student('Roshan',101,2011,"Maths")
Marur = Student('Marur',"102",2012,"History")

# %%
Roshan.name,Roshan.joining_date,Roshan.current_topic,Roshan.rollno
# Out:
# ('Roshan', 2011, 'Maths', 101)

# %%
Roshan.cr_topic()
# Out:
# This is your current topic :-  Maths

# %%
Roshan.str_rollno()
# Out:
# '101'

# %%
Roshan.duration(2021)
# Out:
# This is yoour durartion :- 10

# %%
print(Roshan)
# Out:
# This is the student class where they can tried to input there own data and they can try to fetch it.

# %%
Marun1 = Student(['Roshan','Manoj','Shree','Nilesh'],[101,102,103,104],2010,['Geography',"Maths","History","Science"])

# %%
Marun1.name_parsering()
# Out:
# Roshan
# Manoj
# Shree
# Nilesh

# %%
Marur.name_parsering()
# Out:
# Provided list is not in the form of list.

# %%
class Student:
    def __init__(self,name,rollno,joining_date,current_topic):
        self.name = name
        self.rollno = rollno
        self.joining_date = joining_date
        self.current_topic = current_topic
        
    def name_parsering(self):
        if type(self.name)==list:
            for i in self.name:
                print(i)
        else:
            return self.name
    def cr_topic(self):
        return print("This is your current topic :- ",self.current_topic)
    
    try:
        def str_rollno(self):
            if type(self.rollno)==str:
                print("Don't do anything.")
            else:
                return str(self.rollno)
    except Exception as e:
        print('This is the error msg',e)
        
    
    def duration(self,current_date):
        return print("This is yoour durartion :-",current_date - self.joining_date)
    
    def update_name(self,other):
        self.name = other
        
            
    
    def __str__(self):
        return "This is the student class where they can tried to input there own data and they can try to fetch it."

# %%
std1 = Student('Harish',101,2011,'History')

# %%
std1.name,std1.rollno,std1.joining_date,std1.current_topic
# Out:
# ('Harish', 101, 2011, 'History')

# %%
std1.update_name('Roshan')

# %%
std1.name,std1.rollno,std1.joining_date,std1.current_topic
# Out:
# ('Roshan', 101, 2011, 'History')

# %% [markdown]
# ## Task 1

# %%
import logging as lg
lg.basicConfig(filename = "OOPs.log",level=lg.ERROR)
class Data:
    def __init__(self,File_name,File_type,Date,Size):
        self.File_name =File_name
        self.File_type =File_type
        self.Date=Date
        self.Size = Size
        
    def file_open(self):
        try:
            f = open(self.File_name+"."+self.File_type,mode='w')
            f.write('I am Roshan')
            f.close()
        except Exception as e:
            self.logging(e)
            print('This is an error',e)
        
    def file_read(self):
        try:
            f = open(self.File_name+"."+self.File_type,mode='r')
            f.readlines()
            f.close()
        except Exception as e:
            self.logging(e)
            print('This is an error',e)
        
        
    def file_append(self):
        try:
            f = open(self.File_name+"."+self.File_type,mode='a')
            f.write('I am from India.')
            f.close()
        except Exception as e:
            self.logging(e)
            print('This is an error',e)
    def logging(self,log):
        lg.error(log)

# %%
data1 = Data('text12', 'txt',2021,"1-MB")

# %%
data1.File_name,data1.Date,data1.File_type,data1.Size
# Out:
# ('text12', 2021, 'txt', '1-MB')

# %%
data1.file_open()

# %%
data1.file_read()

# %%
data1.file_append()

# %% [markdown]
# ## Thanks !!
