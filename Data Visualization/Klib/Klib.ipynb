# %%
import klib
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Link :- https://klib.readthedocs.io/en/latest/

# %% [markdown]
# ## Describe

# %%
# klib.describe - functions for visualizing datasets
- klib.cat_plot(df) # returns a visualization of the number and frequency of categorical features
- klib.corr_mat(df) # returns a color-encoded correlation matrix
- klib.corr_plot(df) # returns a color-encoded heatmap, ideal for correlations
- klib.dist_plot(df) # returns a distribution plot for every numeric feature
- klib.missingval_plot(df) # returns a figure containing information about missing values

# %%
klib.cat_plot(df,(20,20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a63f2f8c3130> in <module>
# ----> 1 klib.cat_plot(df,(20,20))
#
# F:\anaconda\lib\site-packages\klib\describe.py in cat_plot(data, figsize, top, bottom, bar_color_top, bar_color_bottom)
#     116         data[col] = data[col].rolling(2, min_periods=1).mean()
#     117
# --> 118         value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
#     119         value_counts_idx_bot = [elem[:20] for elem in value_counts_idx_bot]
#     120         sum_top = sum(value_counts_top)
#
# F:\anaconda\lib\site-packages\klib\describe.py in <listcomp>(.0)
#     116         data[col] = data[col].rolling(2, min_periods=1).mean()
#     117
# --> 118         value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
#     119         value_counts_idx_bot = [elem[:20] for elem in value_counts_idx_bot]
#     120         sum_top = sum(value_counts_top)
#
# TypeError: 'bool' object is not subscriptable

# %%
klib.cat_plot(df, top=4, bottom=4) # representation of the 4 most & least common values in each categorical column
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-7e95a934f3c8> in <module>
# ----> 1 klib.cat_plot(df, top=4, bottom=4) # representation of the 4 most & least common values in each categorical column
#
# F:\anaconda\lib\site-packages\klib\describe.py in cat_plot(data, figsize, top, bottom, bar_color_top, bar_color_bottom)
#     116         data[col] = data[col].rolling(2, min_periods=1).mean()
#     117
# --> 118         value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
#     119         value_counts_idx_bot = [elem[:20] for elem in value_counts_idx_bot]
#     120         sum_top = sum(value_counts_top)
#
# F:\anaconda\lib\site-packages\klib\describe.py in <listcomp>(.0)
#     116         data[col] = data[col].rolling(2, min_periods=1).mean()
#     117
# --> 118         value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
#     119         value_counts_idx_bot = [elem[:20] for elem in value_counts_idx_bot]
#     120         sum_top = sum(value_counts_top)
#
# TypeError: 'bool' object is not subscriptable

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 313.7 KB

# %%
df2=klib.data_cleaning(df)
df2
# Out:
# Shape of cleaned data: (784, 15)Remaining NAs: 692
#
# Changes:
# Dropped rows: 107
#      of which 107 duplicates. (Rows: [47, 76, 77, 87, 95, 101, 121, 133, 173, 196, 198, 201, 213, 223, 241, 260, 274, 295, 300, 304, 313, 320, 324, 335, 343, 354, 355, 358, 359, 364, 368, 384, 409, 410, 413, 418, 420, 425, 428, 431, 454, 459, 464, 466, 470, 476, 481, 485, 488, 490, 494, 500, 511, 521, 522, 526, 531, 560, 563, 564, 568, 573, 588, 589, 598, 601, 612, 613, 614, 635, 636, 640, 641, 644, 646, 650, 656, 666, 674, 692, 696, 709, 732, 733, 734, 738, 739, 757, 758, 760, 773, 790, 792, 800, 808, 832, 837, 838, 844, 846, 859, 863, 870, 877, 878, 884, 886])
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 177
# Reduced memory by at least: 0.06 MB (-75.0%)
#      survived  pclass     sex   age  sibsp  parch       fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.250000        S  Third
# 1           1       1  female  38.0      1      0  71.283302        C  First
# 2           1       3  female  26.0      0      0   7.925000        S  Third
# 3           1       1  female  35.0      1      0  53.099998        S  First
# 4           0       3    male  35.0      0      0   8.050000        S  Third
# ..        ...     ...     ...   ...    ...    ...        ...      ...    ...
# 779         0       3  female  39.0      0      5  29.125000        Q  Third
# 780         1       1  female  19.0      0      0  30.000000        S  First
# 781         0       3  female   NaN      1      2  23.450001        S  Third
# 782         1       1    male  26.0      0      0  30.000000        C  First
# 783         0       3    male  32.0      0      0   7.750000        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 779  woman       False  NaN   Queenstown    no  False
# 780  woman       False    B  Southampton   yes   True
# 781  woman       False  NaN  Southampton    no  False
# 782    man        True    C    Cherbourg   yes   True
# 783    man        True  NaN   Queenstown    no   True
#
# [784 rows x 15 columns]

# %%
df3 = pd.concat([df.dtypes,df2.dtypes],axis=1)
df3
# Out:
#                     0         1
# survived        int64      int8
# pclass          int64      int8
# sex            object  category
# age           float64   float32
# sibsp           int64      int8
# parch           int64      int8
# fare          float64   float32
# embarked       object  category
# class        category  category
# who            object  category
# adult_male       bool   boolean
# deck         category  category
# embark_town    object  category
# alive          object  category
# alone            bool   boolean

# %%
klib.corr_mat(df)
# Out:
# <style  type="text/css" >
# #T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col0,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col4,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col5,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col1,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col3,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col4,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col6,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col7,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col2,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col5,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col6,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col7,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col1,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col3,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col4,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col5,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow4_col0,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow4_col1,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow4_col3,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow4_col4,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow4_col5,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow5_col0,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow5_col2,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow5_col3,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow5_col4,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow5_col5,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow6_col1,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow6_col2,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow6_col6,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow6_col7,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow7_col1,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow7_col2,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow7_col6,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow7_col7{
#             color:  None;
#         }#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col1,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col2,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col3,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col6,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col7,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col0,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col2,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col5,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col0,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col1,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col3,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col4,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col0,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col2,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col6,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col7,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow4_col2,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow4_col6,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow4_col7,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow5_col1,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow5_col6,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow5_col7,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow6_col0,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow6_col3,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow6_col4,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow6_col5,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow7_col0,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow7_col3,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow7_col4,#T_4e898a68_04c4_11ec_b537_d4bed95bf20frow7_col5{
#             color:  #FF3344;
#         }</style><table id="T_4e898a68_04c4_11ec_b537_d4bed95bf20f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >survived</th>        <th class="col_heading level0 col1" >pclass</th>        <th class="col_heading level0 col2" >age</th>        <th class="col_heading level0 col3" >sibsp</th>        <th class="col_heading level0 col4" >parch</th>        <th class="col_heading level0 col5" >fare</th>        <th class="col_heading level0 col6" >adult_male</th>        <th class="col_heading level0 col7" >alone</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4e898a68_04c4_11ec_b537_d4bed95bf20flevel0_row0" class="row_heading level0 row0" >survived</th>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col1" class="data row0 col1" >-0.34</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col2" class="data row0 col2" >-0.08</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col3" class="data row0 col3" >-0.04</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col4" class="data row0 col4" >0.08</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col5" class="data row0 col5" >0.26</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col6" class="data row0 col6" >-0.56</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow0_col7" class="data row0 col7" >-0.20</td>
#             </tr>
#             <tr>
#                         <th id="T_4e898a68_04c4_11ec_b537_d4bed95bf20flevel0_row1" class="row_heading level0 row1" >pclass</th>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col0" class="data row1 col0" >-0.34</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col2" class="data row1 col2" >-0.37</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col3" class="data row1 col3" >0.08</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col4" class="data row1 col4" >0.02</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col5" class="data row1 col5" >-0.55</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col6" class="data row1 col6" >0.09</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow1_col7" class="data row1 col7" >0.14</td>
#             </tr>
#             <tr>
#                         <th id="T_4e898a68_04c4_11ec_b537_d4bed95bf20flevel0_row2" class="row_heading level0 row2" >age</th>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col0" class="data row2 col0" >-0.08</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col1" class="data row2 col1" >-0.37</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col3" class="data row2 col3" >-0.31</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col4" class="data row2 col4" >-0.19</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col5" class="data row2 col5" >0.10</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col6" class="data row2 col6" >0.28</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow2_col7" class="data row2 col7" >0.20</td>
#             </tr>
#             <tr>
#                         <th id="T_4e898a68_04c4_11ec_b537_d4bed95bf20flevel0_row3" class="row_heading level0 row3" >sibsp</th>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col0" class="data row3 col0" >-0.04</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col1" class="data row3 col1" >0.08</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col2" class="data row3 col2" >-0.31</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col4" class="data row3 col4" >0.41</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col5" class="data row3 col5" >0.16</td>
#                         <td id="T_4e898a68_04c4_11ec_b537_d4bed95bf20frow3_col

# %%
klib.corr_plot(df)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.corr_plot(df,target='age')
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %% [markdown]
# ## Cleaning.

# %%
# klib.clean - functions for cleaning datasets
- klib.data_cleaning(df) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
- klib.clean_column_names(df) # cleans and standardizes column names, also called inside data_cleaning()
- klib.convert_datatypes(df) # converts existing to more efficient dtypes, also called inside data_cleaning()
- klib.drop_missing(df) # drops missing values, also called in data_cleaning()
- klib.mv_col_handling(df) # drops features with high ratio of missing vals based on informational content
- klib.pool_duplicate_subsets(df) # pools subset of cols based on duplicates with min. loss of information

# %%
klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (784, 15)Remaining NAs: 692
#
# Changes:
# Dropped rows: 107
#      of which 107 duplicates. (Rows: [47, 76, 77, 87, 95, 101, 121, 133, 173, 196, 198, 201, 213, 223, 241, 260, 274, 295, 300, 304, 313, 320, 324, 335, 343, 354, 355, 358, 359, 364, 368, 384, 409, 410, 413, 418, 420, 425, 428, 431, 454, 459, 464, 466, 470, 476, 481, 485, 488, 490, 494, 500, 511, 521, 522, 526, 531, 560, 563, 564, 568, 573, 588, 589, 598, 601, 612, 613, 614, 635, 636, 640, 641, 644, 646, 650, 656, 666, 674, 692, 696, 709, 732, 733, 734, 738, 739, 757, 758, 760, 773, 790, 792, 800, 808, 832, 837, 838, 844, 846, 859, 863, 870, 877, 878, 884, 886])
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 177
# Reduced memory by at least: 0.06 MB (-75.0%)
#      survived  pclass     sex   age  sibsp  parch       fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.250000        S  Third
# 1           1       1  female  38.0      1      0  71.283302        C  First
# 2           1       3  female  26.0      0      0   7.925000        S  Third
# 3           1       1  female  35.0      1      0  53.099998        S  First
# 4           0       3    male  35.0      0      0   8.050000        S  Third
# ..        ...     ...     ...   ...    ...    ...        ...      ...    ...
# 779         0       3  female  39.0      0      5  29.125000        Q  Third
# 780         1       1  female  19.0      0      0  30.000000        S  First
# 781         0       3  female   NaN      1      2  23.450001        S  Third
# 782         1       1    male  26.0      0      0  30.000000        C  First
# 783         0       3    male  32.0      0      0   7.750000        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 779  woman       False  NaN   Queenstown    no  False
# 780  woman       False    B  Southampton   yes   True
# 781  woman       False  NaN  Southampton    no  False
# 782    man        True    C    Cherbourg   yes   True
# 783    man        True  NaN   Queenstown    no   True
#
# [784 rows x 15 columns]

# %%
klib.clean_column_names(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
klib.convert_datatypes(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch       fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.250000        S   Third
# 1           1       1  female  38.0      1      0  71.283302        C   First
# 2           1       3  female  26.0      0      0   7.925000        S   Third
# 3           1       1  female  35.0      1      0  53.099998        S   First
# 4           0       3    male  35.0      0      0   8.050000        S   Third
# ..        ...     ...     ...   ...    ...    ...        ...      ...     ...
# 886         0       2    male  27.0      0      0  13.000000        S  Second
# 887         1       1  female  19.0      0      0  30.000000        S   First
# 888         0       3  female   NaN      1      2  23.450001        S   Third
# 889         1       1    male  26.0      0      0  30.000000        C   First
# 890         0       3    male  32.0      0      0   7.750000        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
klib.drop_missing(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
klib.mv_col_handling(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 0      man        True  Southampton    no  False
# 1    woman       False    Cherbourg   yes  False
# 2    woman       False  Southampton   yes   True
# 3    woman       False  Southampton   yes  False
# 4      man        True  Southampton    no   True
# ..     ...         ...          ...   ...    ...
# 886    man        True  Southampton    no   True
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
klib.pool_duplicate_subsets(df)
# Out:
#       age  pooled_vars
# 0    22.0            0
# 1    38.0            1
# 2    26.0            2
# 3    35.0            3
# 4    35.0            4
# ..    ...          ...
# 886  27.0          134
# 887  19.0          887
# 888   NaN          888
# 889  26.0          889
# 890  32.0          116
#
# [891 rows x 2 columns]

# %%
klib.pool_duplicate_subsets(df)
# Out:
#       age  pooled_vars
# 0    22.0            0
# 1    38.0            1
# 2    26.0            2
# 3    35.0            3
# 4    35.0            4
# ..    ...          ...
# 886  27.0          134
# 887  19.0          887
# 888   NaN          888
# 889  26.0          889
# 890  32.0          116
#
# [891 rows x 2 columns]

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# ## Preprocessing.

# %%
# klib.preprocess - functions for data preprocessing (feature selection, scaling, ...)
- klib.train_dev_test_split(df) # splits a dataset and a label into train, optionally dev and test sets
- klib.feature_selection_pipe() # provides common operations for feature selection
- klib.num_pipe() # provides common operations for preprocessing of numerical data
- klib.cat_pipe() # provides common operations for preprocessing of categorical data
- klib.preprocess.ColumnSelector() # selects num or cat columns, ideal for a Feature Union or Pipeline
- klib.preprocess.PipeInfo() # prints out the shape of the data at the specified step of a Pipeline

# %%
klib.train_dev_test_split(df,'pclass',test_size=0.3,random_state=42)
# Out:
# (     survived     sex   age  sibsp  parch      fare embarked   class    who  \
#  570         1    male  62.0      0      0   10.5000        S  Second    man
#  787         0    male   8.0      4      1   29.1250        Q   Third  child
#  74          1    male  32.0      0      0   56.4958        S   Third    man
#  113         0  female  20.0      1      0    9.8250        S   Third  woman
#  635         1  female  28.0      0      0   13.0000        S  Second  woman
#  ..        ...     ...   ...    ...    ...       ...      ...     ...    ...
#  106         1  female  21.0      0      0    7.6500        S   Third  woman
#  270         0    male   NaN      0      0   31.0000        S   First    man
#  860         0    male  41.0      2      0   14.1083        S   Third    man
#  435         1  female  14.0      1      2  120.0000        S   First  child
#  102         0    male  21.0      0      1   77.2875        S   First    man
#
#       adult_male deck  embark_town alive  alone
#  570        True  NaN  Southampton   yes   True
#  787       False  NaN   Queenstown    no  False
#  74         True  NaN  Southampton   yes   True
#  113       False  NaN  Southampton    no  False
#  635       False  NaN  Southampton   yes   True
#  ..          ...  ...          ...   ...    ...
#  106       False  NaN  Southampton   yes   True
#  270        True  NaN  Southampton    no   True
#  860        True  NaN  Southampton    no  False
#  435       False    B  Southampton   yes  False
#  102        True    D  Southampton    no  False
#
#  [534 rows x 14 columns],
#       survived     sex   age  sibsp  parch     fare embarked   class    who  \
#  370         1    male  25.0      1      0  55.4417        C   First    man
#  597         0    male  49.0      0      0   0.0000        S   Third    man
#  599         1    male  49.0      1      0  56.9292        C   First    man
#  746         0    male  16.0      1      1  20.2500        S   Third    man
#  594         0    male  37.0      1      0  26.0000        S  Second    man
#  ..        ...     ...   ...    ...    ...      ...      ...     ...    ...
#  133         1  female  29.0      1      0  26.0000        S  Second  woman
#  182         0    male   9.0      4      2  31.3875        S   Third  child
#  259         1  female  50.0      0      1  26.0000        S  Second  woman
#  582         0    male  54.0      0      0  26.0000        S  Second    man
#  327         1  female  36.0      0      0  13.0000        S  Second  woman
#
#       adult_male deck  embark_town alive  alone
#  370        True    E    Cherbourg   yes  False
#  597        True  NaN  Southampton    no   True
#  599        True    A    Cherbourg   yes  False
#  746        True  NaN  Southampton    no  False
#  594        True  NaN  Southampton    no  False
#  ..          ...  ...          ...   ...    ...
#  133       False  NaN  Southampton   yes  False
#  182       False  NaN  Southampton    no  False
#  259       False  NaN  Southampton   yes  False
#  582        True  NaN  Southampton    no   True
#  327       False    D  Southampton   yes   True
#
#  [89 rows x 14 columns],
#       survived     sex   age  sibsp  parch     fare embarked   class    who  \
#  350         0    male  23.0      0      0   9.2250        S   Third    man
#  212         0    male  22.0      0      0   7.2500        S   Third    man
#  678         0  female  43.0      1      6  46.9000        S   Third  woman
#  534         0  female  30.0      0      0   8.6625        S   Third  woman
#  483         1  female  63.0      0      0   9.5875        S   Third  woman
#  ..        ...     ...   ...    ...    ...      ...      ...     ...    ...
#  811         0    male  39.0      0      0  24.1500        S   Third    man
#  344         0    male  36.0      0      0  13.0000        S  Second    man
#  375         1  female   NaN      1      0  82.1708        C   First  woman
#  585         1  female  18.0      0      2  79.6500        S   First  woman
#  552         0    male   NaN      0      0   7.8292        Q   Third    man
#
#       adult_male deck  embark_town alive  alone
#  350        True  NaN  Southampton    no   True
#  212        True  NaN  Southampton    no   True
#  678       False  NaN  Southampton    no  False
#  534       False  NaN  Southampton    no   True
#  483       False  NaN  Southampton   yes   True
#  ..          ...  ...          ...   ...    ...
#  811        True  NaN  Southampton    no   True
#  344        True  NaN  Southampton    no   True
#  375       False  NaN    Cherbourg   yes  False
#  585       False    E  Southampton   yes  False
#  552        True  NaN   Queenstown    no   True
#
#  [268 rows x 14 columns],
#  570    2
#  787    3
#  74     3
#  113    3
#  635    2
#        ..
#  106    3
#  270    1
#  860    3
#  435    1
#  102    1
#  Name: pclass, Length: 534, dtype: int64,
#  370    1
#  597    3
#  599    1
#  746    3
#  594    2
#        ..
#  133    2
#  182    3
#  259    2
#  582    2
#  327    2
#  Name: pclass, Length: 89, dtype: int64,
#  350    3
#  212    3
#  678    3
#  534    3
#  483    3
#        ..
#  811    3
#  344    2
#  375    1
#  585    1
#  552    3
#  Name: pclass, Length: 268, dtype: int64)

# %%
klib.feature_selection_pipe()
# Out:
# Pipeline(steps=[('variancethreshold', VarianceThreshold(threshold=0.1)),
#                 ('pipeinfo-1', PipeInfo(name='after var_thresh')),
#                 ('selectfrommodel',
#                  SelectFromModel(estimator=LassoCV(cv=4, random_state=408),
#                                  threshold='0.1*median')),
#                 ('pipeinfo-2', PipeInfo(name='after select_from_model')),
#                 ('selectpercentile', SelectPercentile(percentile=95)),
#                 ('pipeinfo-3', PipeInfo(name='after select_percentile'))])

# %%
klib.num_pipe()
# Out:
# Pipeline(steps=[('columnselector', ColumnSelector()),
#                 ('iterativeimputer',
#                  IterativeImputer(estimator=ExtraTreesRegressor(n_estimators=25,
#                                                                 n_jobs=4,
#                                                                 random_state=408),
#                                   random_state=408)),
#                 ('robustscaler', RobustScaler())])

# %%
klib.cat_pipe()
# Out:
# Pipeline(steps=[('columnselector', ColumnSelector(num=False)),
#                 ('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('onehotencoder', OneHotEncoder(handle_unknown='ignore')),
#                 ('pipeinfo', PipeInfo(name='after encoding categorical data')),
#                 ('maxabsscaler', MaxAbsScaler())])

# %%
klib.preprocess.ColumnSelector(df)
# Out:
# ColumnSelector(num=     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3...
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns])

# %%
klib.preprocess.PipeInfo(df)
# Out:
# PipeInfo(name=     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  3...
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns])

# %% [markdown]
# ## Another Example.

# %%
data = sns.load_dataset('tips')

# %%
klib.cat_plot(data, top=4, bottom=4) # representation of the 4 most & least common values in each categorical column
# Out:
# GridSpec(6, 4)

# %%
klib.corr_mat(data)
# Out:
# <style  type="text/css" >
# #T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow0_col0,#T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow0_col1,#T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow0_col2,#T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow1_col0,#T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow1_col1,#T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow1_col2,#T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow2_col0,#T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow2_col1,#T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow2_col2{
#             color:  None;
#         }</style><table id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >size</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20flevel0_row0" class="row_heading level0 row0" >total_bill</th>
#                         <td id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow0_col1" class="data row0 col1" >0.68</td>
#                         <td id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow0_col2" class="data row0 col2" >0.60</td>
#             </tr>
#             <tr>
#                         <th id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20flevel0_row1" class="row_heading level0 row1" >tip</th>
#                         <td id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow1_col0" class="data row1 col0" >0.68</td>
#                         <td id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow1_col2" class="data row1 col2" >0.49</td>
#             </tr>
#             <tr>
#                         <th id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20flevel0_row2" class="row_heading level0 row2" >size</th>
#                         <td id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow2_col0" class="data row2 col0" >0.60</td>
#                         <td id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow2_col1" class="data row2 col1" >0.49</td>
#                         <td id="T_0d911d68_04c7_11ec_bc13_d4bed95bf20frow2_col2" class="data row2 col2" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
klib.corr_plot(df)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
 klib.missingval_plot(data)
# Out:
# No missing values found in the dataset.
